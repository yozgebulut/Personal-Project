# %% [markdown]
# ![Metamy%20Logo3.jpg](attachment:Metamy%20Logo3.jpg)

# %% [markdown]
# # DATA ANALYSIS WITH PYTHON

# %% [markdown]
# # Data Analysis with Python Capstone Project

# %% [markdown]
# # Netflix

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Information on the Data Set

# %% [markdown]
# **This dataset contains more than 8,500 Netflix movies and TV shows, including cast members, duration, and genre.**<br><br>
# **It contains titles added as recently as late September 2021.**
#
# **Not sure where to begin? Scroll to the bottom to find challenges!**
#
# **Netflix! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.**
#
# **A talent agency has hired you with your team to analyze patterns in the professional relationships of cast members and directors. You can limit the actors to the first four names listed in cast. The client is interested in any insights you can derive from your Netflix network analysis, such as actor/actor and actor/director pairs that work most closely together, most popular actors and directors to work with, and graph differences over time. You will need to prepare a report that is accessible to a broad audience. It will need to outline your motivation, analysis steps, findings, and conclusions.**
#
#
# **Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your data manipulation skills. One of your friend in your team has performed an initial analysis and said that  the average duration of movies has been declining. He believes if your team can explain some of the factors that may be contributing to the shortening movie lengths.**
#
#
# **You have been supplied with the dataset netflix_data.csv , along with the following table detailing the column names and descriptions:**

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Your friend suspects that movies are getting shorter and they've found some initial evidence of this. Having peaked your interest, you will perform exploratory data analysis on the "netflix_data.csv" to understand what may be contributing to movies getting shorter over time. Your analysis may follow the following steps as a starting point:**<br><br>
#
#
#
#
# - Investigate and subset the Netflix data by "Movie" type, keeping only the columns "title", "country", "genre", "release_year", "duration", saving this into a new DataFrame called netflix_movies.
#
# - Filter netflix_movies to find the movies that are shorter than 60 minutes, and inspect the result to find possible contributing factors.
#
# - Using a for loop, assign colors of your choice to four genre groups from netflix_movies, ("Children", "Documentaries", "Stand-Up", and "Other") saving them to a colors list, and use this to initialize a figure object and create a scatter plot for movie duration by release year using the labels "Release year" for the x-axis, "Duration (min)" for the y-axis, and the title "Movie Duration by Year of Release".
#
#
# - After inspecting the plot, answer the question "Are we certain that movies are getting shorter?" by assigning either "yes", "no", or "maybe" to the variable answer.

# %% [markdown]
# **Again, your client is interested in any insights you can derive from data set. For instance, following analysis might be helpful:**<br><br>
#
# - Replacing missing countries with "Not Specify", missing directors with "No Director", missing cast with "No Cast"
#
#
# - How much variety exists in Netflix's offering? Base this on three variables: type, country, and listed_in.
#
#
# - Has Netflix invested more in certain genres (see listed_in) in recent years? What about certain age groups (see ratings)?

# %%
# don't display warning
import warnings
warnings.filterwarnings("ignore")

# %%
# import related libraries
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from collections import Counter

# in order to set the parameters that control the general style of the plots. 
plt.rcParams["figure.figsize"] = (10, 6)
sns.set_style("whitegrid")

# in order to set the value of the specified option.
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# to set it "100" to display all rows in the dataframe
pd.set_option('display.max_rows', 100)

#  to set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %%
# fetch netflix_dataset file
df = pd.read_csv("netflix_dataset.csv", index_col=0)

# %%
# replica for df
df_copy = df.copy()

# %% [markdown]
# ## <span class="burk">Getting to Know a Dataset</span>

# %% [markdown]
# ### Initial Exploration

# %%
# display first 5 record
df.head(5)
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# s2       September 24, 2021          2021  TV-MA  2 Seasons
# s3       September 24, 2021          2021  TV-MA   1 Season
# s4       September 24, 2021          2021  TV-MA   1 Season
# s5       September 24, 2021          2021  TV-MA  2 Seasons
#
#                                                  listed_in  \
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...

# %%
# display last 5 record
df.tail(5)
# Out:
#             type        title         director  \
# show_id
# s8803      Movie       Zodiac    David Fincher
# s8804    TV Show  Zombie Dumb              NaN
# s8805      Movie   Zombieland  Ruben Fleischer
# s8806      Movie         Zoom     Peter Hewitt
# s8807      Movie       Zubaan      Mozez Singh
#
#                                                       cast        country  \
# show_id
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# s8804                                                  NaN            NaN
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#                 date_added  release_year rating   duration  \
# show_id
# s8803    November 20, 2019          2007      R    158 min
# s8804         July 1, 2019          2018  TV-Y7  2 Seasons
# s8805     November 1, 2019          2009      R     88 min
# s8806     January 11, 2020          2006     PG     88 min
# s8807        March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# show_id
# s8803                    Cult Movies, Dramas, Thrillers
# s8804            Kids' TV, Korean TV Shows, TV Comedies
# s8805                           Comedies, Horror Movies
# s8806                Children & Family Movies, Comedies
# s8807    Dramas, International Movies, Music & Musicals
#
#                                                description
# show_id
# s8803    A political cartoonist, a crime reporter and a...
# s8804    While living alone in a spooky town, a young g...
# s8805    Looking to survive in a world taken over by zo...
# s8806    Dragged from civilian life, a former superhero...
# s8807    A scrappy but poor boy worms his way into a ty...

# %%
# display random 5 record
df.sample(5)
# Out:
#             type                       title director  \
# show_id
# s194     TV Show                        D.P.      NaN
# s3795    TV Show           Historical Roasts      NaN
# s6499    TV Show            Click for Murder      NaN
# s5799      Movie  Jandino: Whatever it Takes      NaN
# s4609    TV Show     Three Wives One Husband      NaN
#
#                                                       cast         country  \
# show_id
# s194     Jung Hae-in, Koo Kyo-hwan, Kim Sung-kyun, Son ...   , South Korea
# s3795    Jeff Ross, Bob Saget, James Adomian, Rachel Fe...   United States
# s6499                                      Donal MacIntyre  United Kingdom
# s5799                                     Jandino Asporaat  United Kingdom
# s4609                                                  NaN  United Kingdom
#
#                  date_added  release_year rating  duration  \
# show_id
# s194        August 27, 2021          2021  TV-MA  1 Season
# s3795          May 27, 2019          2019  TV-MA  1 Season
# s6499    September 17, 2017          2017  TV-14  1 Season
# s5799     September 9, 2016          2016  TV-MA    94 min
# s4609       October 1, 2018          2018  TV-14  1 Season
#
#                                                  listed_in  \
# show_id
# s194                     International TV Shows, TV Dramas
# s3795            Stand-Up Comedy & Talk Shows, TV Comedies
# s6499         British TV Shows, Crime TV Shows, Docuseries
# s5799                                      Stand-Up Comedy
# s4609    British TV Shows, International TV Shows, Real...
#
#                                                description
# show_id
# s194     A young private’s assignment to capture army d...
# s3795    "Roastmaster General" Jeff Ross and a slew of ...
# s6499    Crime journalist Donal MacIntyre reveals how d...
# s5799    Jandino Asporaat riffs on the challenges of ra...
# s4609    A film crew captures a year in the life of mod...

# %%
# display dfs dimension
df.shape
# Out:
# (8807, 11)

# %%
# display dfs columns name
df.columns
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# display dfs values
df.values
# Out:
# array([['Movie', 'Dick Johnson Is Dead', 'Kirsten Johnson', ...,
#         '90 min', 'Documentaries',
#         'As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.'],
#        ['TV Show', 'Blood & Water', nan, ..., '2 Seasons',
#         'International TV Shows, TV Dramas, TV Mysteries',
#         'After crossing paths at a party, a Cape Town teen sets out to prove whether a private-school swimming star is her sister who was abducted at birth.'],
#        ['TV Show', 'Ganglands', 'Julien Leclercq', ..., '1 Season',
#         'Crime TV Shows, International TV Shows, TV Action & Adventure',
#         'To protect his family from a powerful drug lord, skilled thief Mehdi and his expert team of robbers are pulled into a violent and deadly turf war.'],
#        ...,
#        ['Movie', 'Zombieland', 'Ruben Fleischer', ..., '88 min',
#         'Comedies, Horror Movies',
#         'Looking to survive in a world taken over by zombies, a dorky college student teams with an urban roughneck and a pair of grifter sisters.'],
#        ['Movie', 'Zoom', 'Peter Hewitt', ..., '88 min',
#         'Children & Family Movies, Comedies',
#         'Dragged from civilian life, a former superhero must train a new crop of youthful saviors when the military preps for an attack by a familiar villain.'],
#        ['Movie', 'Zubaan', 'Mozez Singh', ..., '111 min',
#         'Dramas, International Movies, Music & Musicals',
#         "A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past."]],
#       dtype=object)

# %%
# inquire information about dfs columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, s1 to s8807
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
#  10  description   8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 825.7+ KB

# %%
# Generate descriptive statistics about dfs numeric columns
df.describe().T
# Out:
#                 count     mean   std      min      25%      50%      75%  \
# release_year 8807.000 2014.180 8.819 1925.000 2013.000 2017.000 2019.000
#
#                   max
# release_year 2021.000

# %%
# Generate descriptive statistics about dfs categorical columns
df.describe(include = "O")
# Out:
#          type                 title       director                cast  \
# count    8807                  8807           6173                7982
# unique      2                  8807           4528                7692
# top     Movie  Dick Johnson Is Dead  Rajiv Chilaka  David Attenborough
# freq     6131                     1             19                  19
#
#               country       date_added rating  duration  \
# count            7976             8797   8803      8804
# unique            748             1767     17       220
# top     United States  January 1, 2020  TV-MA  1 Season
# freq             2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# count                                                8807
# unique                                               8775
# top     Paranormal activity at a lush, abandoned prope...
# freq                                                    4

# %%
# Generate descriptive statistics about dfs numeric and categorical columns
df.describe(include = "all")
# Out:
#          type                 title       director                cast  \
# count    8807                  8807           6173                7982
# unique      2                  8807           4528                7692
# top     Movie  Dick Johnson Is Dead  Rajiv Chilaka  David Attenborough
# freq     6131                     1             19                  19
# mean      NaN                   NaN            NaN                 NaN
# std       NaN                   NaN            NaN                 NaN
# min       NaN                   NaN            NaN                 NaN
# 25%       NaN                   NaN            NaN                 NaN
# 50%       NaN                   NaN            NaN                 NaN
# 75%       NaN                   NaN            NaN                 NaN
# max       NaN                   NaN            NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# count            7976             8797      8807.000   8803      8804
# unique            748             1767           NaN     17       220
# top     United States  January 1, 2020           NaN  TV-MA  1 Season
# freq             2818              109           NaN   3207      1793
# mean              NaN              NaN      2014.180    NaN       NaN
# std               NaN              NaN         8.819    NaN       NaN
# min               NaN              NaN      1925.000    NaN       NaN
# 25%               NaN              NaN      2013.000    NaN       NaN
# 50%               NaN              NaN      2017.000    NaN       NaN
# 75%               NaN              NaN      2019.000    NaN       NaN
# max               NaN              NaN      2021.000    NaN       NaN
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
# mean                             NaN
# std                              NaN
# min                              NaN
# 25%                              NaN
# 50%                              NaN
# 75%                              NaN
# max                              NaN
#
#                                               description
# count                                                8807
# unique                                               8775
# top     Paranormal activity at a lush, abandoned prope...
# freq                                                    4
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
# It does the checking DF column by column.
def check_dataframe(col):
    print("column name : ", col)
    print("--------------------------------")
    print("Percentage_of_Nulls        : ", "%", round(df[col].isnull().sum() * 100 /df.shape[0], 2))
    print("Num_of_Nulls               : ", df[col].isnull().sum())
    print("Num_of_Unique              : ", df[col].nunique())
    print("Type of the Column         : ", df[col].dtypes)
    print(df[col].value_counts(dropna = False))
    print(""*30)
    print("\n")

# %%
# check columns with check_dataframe function
for col in df.columns:
    check_dataframe(col)
# Out:
# column name :  type
# --------------------------------
# Percentage_of_Nulls        :  % 0.0
# Num_of_Nulls               :  0
# Num_of_Unique              :  2
# Type of the Column         :  object
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64
#
#
#
# column name :  title
# --------------------------------
# Percentage_of_Nulls        :  % 0.0
# Num_of_Nulls               :  0
# Num_of_Unique              :  8807
# Type of the Column         :  object
# Dick Johnson Is Dead                     1
# Ip Man 2                                 1
# Hannibal Buress: Comedy Camisado         1
# Turbo FAST                               1
# Masha's Tales                            1
#                                         ..
# Love for Sale 2                          1
# ROAD TO ROMA                             1
# Good Time                                1
# Captain Underpants Epic Choice-o-Rama    1
# Zubaan                                   1
# Name: title, Length: 8807, dtype: int64
#
#
#
# column name :  director
# --------------------------------
# Percentage_of_Nulls        :  % 29.91
# Num_of_Nulls               :  2634
# Num_of_Unique              :  4528
# Type of the Column         :  object
# NaN                               2634
# Rajiv Chilaka                       19
# Raúl Campos, Jan Suter              18
# Suhas Kadav                         16
# Marcus Raboy                        16
#                                   ...
# Raymie Muzquiz, Stu Livingston       1
# Joe Menendez                         1
# Eric Bross                           1
# Will Eisenberg                       1
# Mozez Singh                          1
# Name: director, Length: 4529, dtype: int64
#
#
#
# column name :  cast
# --------------------------------
# Percentage_of_Nulls        :  % 9.37
# Num_of_Nulls               :  825
# Num_of_Unique              :  7692
# Type of the Column         :  object
# NaN                                                                                                                                                                                           825
# David Attenborough                                                                                                                                                                             19
# Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil                                                                                                        14
# Samuel West                                                                                                                                                                                    10
# Jeff Dunham                                                                                                                                                                                     7
#                                                                                                                                                                                              ...
# Nick Lachey, Vanessa Lachey                                                                                                                                                                     1
# Takeru Sato, Kasumi Arimura, Haru, Kentaro Sakaguchi, Takayuki Yamada, Kendo Kobayashi, Ken Yasuda, Arata Furuta, Suzuki Matsuo, Koichi Yamadera, Arata Iura, Chikako Kaku, Kotaro Yoshida      1
# Toyin Abraham, Sambasa Nzeribe, Chioma Chukwuka Akpotha, Chioma Omeruah, Chiwetalu Agu, Dele Odule, Femi Adebayo, Bayray McNwizu, Biodun Stephen                                                1
# Neeraj Kabi, Geetanjali Kulkarni, Danish Husain, Sheeba Chaddha, Paras Priyadarshan, Anshul Chauhan, Anud Singh Dhaka, Shirin Sewani, Mihir Ahuja, Vasundhara Rajput                            1
# Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy                                                           1
# Name: cast, Length: 7693, dtype: int64
#
#
#
# column name :  country
# --------------------------------
# Percentage_of_Nulls        :  % 9.44
# Num_of_Nulls               :  831
# Num_of_Unique              :  748
# Type of the Column         :  object
# United States                             2818
# India                                      972
# NaN                                        831
# United Kingdom                             419
# Japan                                      245
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 749, dtype: int64
#
#
#
# column name :  date_added
# --------------------------------
# Percentage_of_Nulls        :  % 0.11
# Num_of_Nulls               :  10
# Num_of_Unique              :  1767
# Type of the Column         :  object
# January 1, 2020      109
# November 1, 2019      89
# March 1, 2018         75
# December 31, 2019     74
# October 1, 2018       71
#                     ...
# December 4, 2016       1
# November 21, 2016      1
# November 19, 2016      1
# November 17, 2016      1
# January 11, 2020       1
# Name: date_added, Length: 1768, dtype: int64
#
#
#
# column name :  release_year
# --------------------------------
# Percentage_of_Nulls        :  % 0.0
# Num_of_Nulls               :  0
# Num_of_Unique              :  74
# Type of the Column         :  int64
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
# 2021     592
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# 2010     194
# 2011     185
# 2009     152
# 2008     136
# 2006      96
# 2007      88
# 2005      80
# 2004      64
# 2003      61
# 2002      51
# 2001      45
# 1999      39
# 1997      38
# 2000      37
# 1998      36
# 1993      28
# 1995      25
# 1996      24
# 1992      23
# 1994      22
# 1990      22
# 1988      18
# 1982      17
# 1991      17
# 1989      16
# 1981      13
# 1986      13
# 1984      12
# 1980      11
# 1979      11
# 1983      11
# 1985      10
# 1973      10
# 1976       9
# 1987       8
# 1977       7
# 1974       7
# 1975       7
# 1978       7
# 1972       5
# 1967       5
# 1971       5
# 1960       4
# 1945       4
# 1944       3
# 1955       3
# 1968       3
# 1962       3
# 1943       3
# 1958       3
# 1964       2
# 1969       2
# 1970       2
# 1963       2
# 1956       2
# 1965       2
# 1946       2
# 1942       2
# 1954       2
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: release_year, dtype: int64
#
#
#
# column name :  rating
# --------------------------------
# Percentage_of_Nulls        :  % 0.05
# Num_of_Nulls               :  4
# Num_of_Unique              :  17
# Type of the Column         :  object
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NaN            4
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64
#
#
#
# column name :  duration
# --------------------------------
# Percentage_of_Nulls        :  % 0.03
# Num_of_Nulls               :  3
# Num_of_Unique              :  220
# Type of the Column         :  object
# 1 Season     1793
# 2 Seasons     425
# 3 Seasons     199
# 90 min        152
# 94 min        146
#              ...
# 189 min         1
# 10 min          1
# 3 min           1
# 229 min         1
# 191 min         1
# Name: duration, Length: 221, dtype: int64
#
#
#
# column name :  listed_in
# --------------------------------
# Percentage_of_Nulls        :  % 0.0
# Num_of_Nulls               :  0
# Num_of_Unique              :  514
# Type of the Column         :  object
# Dramas, International Movies                          362
# Documentaries                                         359
# Stand-Up Comedy                                       334
# Comedies, Dramas, International Movies                274
# Dramas, Independent Movies, International Movies      252
#                                                      ...
# Kids' TV, TV Action & Adventure, TV Dramas              1
# TV Comedies, TV Dramas, TV Horror                       1
# Children & Family Movies, Comedies, LGBTQ Movies        1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows      1
# Cult Movies, Dramas, Thrillers                          1
# Name: listed_in, Length: 514, dtype: int64
#
#
#
# column name :  description
# --------------------------------
# Percentage_of_Nulls        :  % 0.0
# Num_of_Nulls               :  0
# Num_of_Unique              :  8775
# Type of the Column         :  object
# Paranormal activity at a lush, abandoned property alarms a group eager to redevelop the site, but the eerie events may not be as unearthly as they think.    4
# Challenged to compose 100 songs before he can marry the girl he loves, a tortured but passionate singer-songwriter embarks on a poignant musical journey.    3
# A surly septuagenarian gets another chance at her 20s after having her photo snapped at a studio that magically takes 50 years off her life.                 3
# Multiple women report their husbands as missing but when it appears they are looking for the same man, a police officer traces their cryptic connection.     3
# Secrets bubble to the surface after a sensual encounter and an unforeseen crime entangle two friends and a woman caught between them.                        2
#                                                                                                                                                             ..
# Sent away to evade an arranged marriage, a 14-year-old begins a harrowing journey of sex work and poverty in the slums of Accra.                             1
# When his partner in crime goes missing, a small-time crook’s life is transformed as he dedicates himself to raising the daughter his friend left behind.     1
# During 1962’s Cuban missile crisis, a troubled math genius finds himself drafted to play in a U.S.-Soviet chess match – and a deadly game of espionage.      1
# A teen's discovery of a vintage Polaroid camera develops into a darker tale when she finds that whoever takes their photo with it dies soon afterward.       1
# A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.                      1
# Name: description, Length: 8775, dtype: int64

# %% [raw]
# ! we have a dataset of 8807 records and 11 fields.
# ! there are duplicate and null records which they must be fixed.
# ! new fields can be derived.
# ! data_added and duration fields need to change their data type.

# %% [markdown]
# ### Data Validation

# %%
# display data type of fields dfs
df.dtypes
# Out:
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# display records with the word "movie" in type field
df[df["type"].isin(["Movie"])]
# Out:
#           type                             title  \
# show_id
# s1       Movie              Dick Johnson Is Dead
# s7       Movie  My Little Pony: A New Generation
# s8       Movie                           Sankofa
# s10      Movie                      The Starling
# s13      Movie                      Je Suis Karl
# ...        ...                               ...
# s8802    Movie                           Zinzana
# s8803    Movie                            Zodiac
# s8805    Movie                        Zombieland
# s8806    Movie                              Zoom
# s8807    Movie                            Zubaan
#
#                               director  \
# show_id
# s1                     Kirsten Johnson
# s7       Robert Cullen, José Luis Ucha
# s8                        Haile Gerima
# s10                     Theodore Melfi
# s13                Christian Schwochow
# ...                                ...
# s8802                  Majid Al Ansari
# s8803                    David Fincher
# s8805                  Ruben Fleischer
# s8806                     Peter Hewitt
# s8807                      Mozez Singh
#
#                                                       cast  \
# show_id
# s1                                                     NaN
# s7       Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# s8       Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# s10      Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# s13      Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# ...                                                    ...
# s8802    Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
# s8803    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# s8805    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# s8806    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# s8807    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                    country  \
# show_id
# s1                                           United States
# s7                                                     NaN
# s8       United States, Ghana, Burkina Faso, United Kin...
# s10                                          United States
# s13                                Germany, Czech Republic
# ...                                                    ...
# s8802                         United Arab Emirates, Jordan
# s8803                                        United States
# s8805                                        United States
# s8806                                        United States
# s8807                                                India
#
#                  date_added  release_year rating duration  \
# show_id
# s1       September 25, 2021          2020  PG-13   90 min
# s7       September 24, 2021          2021     PG   91 min
# s8       September 24, 2021          1993  TV-MA  125 min
# s10      September 24, 2021          2021  PG-13  104 min
# s13      September 23, 2021          2021  TV-MA  127 min
# ...                     ...           ...    ...      ...
# s8802         March 9, 2016          2015  TV-MA   96 min
# s8803     November 20, 2019          2007      R  158 min
# s8805      November 1, 2019          2009      R   88 min
# s8806      January 11, 2020          2006     PG   88 min
# s8807         March 2, 2019          2015  TV-14  111 min
#
#                                                 listed_in  \
# show_id
# s1                                          Documentaries
# s7                               Children & Family Movies
# s8       Dramas, Independent Movies, International Movies
# s10                                      Comedies, Dramas
# s13                          Dramas, International Movies
# ...                                                   ...
# s8802             Dramas, International Movies, Thrillers
# s8803                      Cult Movies, Dramas, Thrillers
# s8805                             Comedies, Horror Movies
# s8806                  Children & Family Movies, Comedies
# s8807      Dramas, International Movies, Music & Musicals
#
#                                                description
# show_id
# s1       As her father nears the end of his life, filmm...
# s7       Equestria's divided. But a bright-eyed hero be...
# s8       On a photo shoot in Ghana, an American model s...
# s10      A woman adjusting to life after a loss contend...
# s13      After most of her family is murdered in a terr...
# ...                                                    ...
# s8802    Recovering alcoholic Talal wakes up inside a s...
# s8803    A political cartoonist, a crime reporter and a...
# s8805    Looking to survive in a world taken over by zo...
# s8806    Dragged from civilian life, a former superhero...
# s8807    A scrappy but poor boy worms his way into a ty...
#
# [6131 rows x 11 columns]

# %%
# display records that do not contain the word "movie" in type field
df[~df["type"].isin(["Movie"])]
# Out:
#             type                  title         director  \
# show_id
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
# s6       TV Show          Midnight Mass    Mike Flanagan
# ...          ...                    ...              ...
# s8796    TV Show        Yu-Gi-Oh! Arc-V              NaN
# s8797    TV Show             Yunus Emre              NaN
# s8798    TV Show              Zak Storm              NaN
# s8801    TV Show     Zindagi Gulzar Hai              NaN
# s8804    TV Show            Zombie Dumb              NaN
#
#                                                       cast  \
# show_id
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# s4                                                     NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# s6       Kate Siegel, Zach Gilford, Hamish Linklater, H...
# ...                                                    ...
# s8796    Mike Liscio, Emily Bauer, Billy Bob Thompson, ...
# s8797    Gökhan Atalay, Payidar Tüfekçioglu, Baran Akbu...
# s8798    Michael Johnston, Jessica Gee-George, Christin...
# s8801    Sanam Saeed, Fawad Khan, Ayesha Omer, Mehreen ...
# s8804                                                  NaN
#
#                                                country          date_added  \
# show_id
# s2                                        South Africa  September 24, 2021
# s3                                                 NaN  September 24, 2021
# s4                                                 NaN  September 24, 2021
# s5                                               India  September 24, 2021
# s6                                                 NaN  September 24, 2021
# ...                                                ...                 ...
# s8796                                    Japan, Canada         May 1, 2018
# s8797                                           Turkey    January 17, 2017
# s8798    United States, France, South Korea, Indonesia  September 13, 2018
# s8801                                         Pakistan   December 15, 2016
# s8804                                              NaN        July 1, 2019
#
#          release_year rating   duration  \
# show_id
# s2               2021  TV-MA  2 Seasons
# s3               2021  TV-MA   1 Season
# s4               2021  TV-MA   1 Season
# s5               2021  TV-MA  2 Seasons
# s6               2021  TV-MA   1 Season
# ...               ...    ...        ...
# s8796            2015  TV-Y7  2 Seasons
# s8797            2016  TV-PG  2 Seasons
# s8798            2016  TV-Y7  3 Seasons
# s8801            2012  TV-PG   1 Season
# s8804            2018  TV-Y7  2 Seasons
#
#                                                  listed_in  \
# show_id
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
# s6                      TV Dramas, TV Horror, TV Mysteries
# ...                                                    ...
# s8796                               Anime Series, Kids' TV
# s8797                    International TV Shows, TV Dramas
# s8798                                             Kids' TV
# s8801    International TV Shows, Romantic TV Shows, TV ...
# s8804               Kids' TV, Korean TV Shows, TV Comedies
#
#                                                description
# show_id
# s2       After crossing paths at a party, a Cape Town t...
# s3       To protect his family from a powerful drug lor...
# s4       Feuds, flirtations and toilet talk go down amo...
# s5       In a city of coaching centers known to train I...
# s6       The arrival of a charismatic young priest brin...
# ...                                                    ...
# s8796    Now that he's discovered the Pendulum Summonin...
# s8797    During the Mongol invasions, Yunus Emre leaves...
# s8798    Teen surfer Zak Storm is mysteriously transpor...
# s8801    Strong-willed, middle-class Kashaf and carefre...
# s8804    While living alone in a spooky town, a young g...
#
# [2676 rows x 11 columns]

# %%
# return a Series containing counts of unique values
df.value_counts()
# Out:
# type     title                                         director             cast                                                                                                                                                            country         date_added          release_year  rating  duration   listed_in                                       description
# Movie    #Alive                                        Cho Il               Yoo Ah-in, Park Shin-hye                                                                                                                                        South Korea     September 8, 2020   2020          TV-MA   99 min     Horror Movies, International Movies, Thrillers  As a grisly virus rampages a city, a lone man stays locked inside his apartment, digitally cut off from seeking help and desperate to find a way out.       1
#          Sakaling Maging Tayo                          JP Habac             McCoy De Leon, Elisse Joson, Bembol Roco, Chai Fonacier, Paulo Angeles, Markus Paterson, Milo Elmido Jr.                                                        Philippines     December 17, 2020   2019          TV-14   90 min     International Movies, Romantic Movies           A college student seizes his chance with a crush when an unexpected encounter turns into a night of bold dares, deep confessions and possible romance.      1
#          Saheb Biwi Aur Gangster Returns               Tigmanshu Dhulia     Irrfan Khan, Jimmy Shergill, Soha Ali Khan, Mahie Gill, Raj Babbar, Deep Raj Rana, Rajiv Gupta, Sitaram Panchal, Rajesh Khera, Mugdha Godse                     India           September 19, 2020  2013          TV-MA   139 min    Dramas, International Movies, Romantic Movies   Knotty love triangles and nefarious schemes arise when a nobleman’s plans to remarry fall into the cunning hands of his first wife and a vengeful rival.    1
#          Saheb Bibi Golaam                             Pratim D. Gupta      Anjan Dutt, Swastika Mukherjee, Ritwick Chakraborty, Parno Mittra, Bikram Chatterjee, Sohag Sen, Sumanta Mukherjee, Arun Mukhopadhyay                           India           January 1, 2017     2016          TV-MA   118 min    Dramas, International Movies                    A charming cabbie, a cop turned assassin and a housewife who’s also a hooker share one thing in common: a bizarre and violent afternoon in Kolkata.         1
#          Sahara                                        Pierre Coré          Robert Naylor, Angela Galuppo, Daniel Brochu, Mark Hauser, Andrew Shaver, Mathew Mackay, Richard Dumont, Brady Moffatt, Rick Jones, Nadia Verrucci, Sonja Ball  France, Canada  May 12, 2017        2017          TV-Y7   86 min     Children & Family Movies                        When his new love is captured by an evil snake charmer, a young cobra and his scorpion best friend set out across the desert on a wild rescue mission.      1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ..
#          Hawaizaada                                    Vibhu Virender Puri  Ayushmann Khurrana, Mithun Chakraborty, Pallavi Sharda, Naman Jain, Jameel Khan                                                                                 India           November 19, 2020   2015          TV-14   129 min    Dramas, International Movies, Romantic Movies   In 1895 Mumbai, spirited Indian lad Shiv Talpade defies British rule and sparse funding – and physics – to build the world's first airplane.                1
#          Havenhurst                                    Andrew C. Erin       Julie Benz, Belle Shouse, Josh Stamberg, Danielle Harris, Douglas Tait, Matt Lasky, Dendrie Taylor, Toby Huss, Jennifer Blanc, Fionnula Flanagan                United States   June 10, 2017       2016          TV-MA   85 min     Horror Movies, Thrillers                        An alcoholic with a tragic past rents an apartment in a building for those in recovery, but soon learns the truth about residents who get "evicted."        1
#          Have a Good Trip: Adventures in Psychedelics  Donick Cary          Nick Offerman, Adam Scott                                                                                                                                       United States   May 11, 2020        2020          TV-MA   86 min     Documentaries                                   Explore hallucinogenic highs and lows as celebrities share funny, mind-blowing tales via animations, reenactments and more in this documentary.             1
#          Have You Seen the Listers?                    Eddie Martin         Anthony Lister                                                                                                                                                  Australia       February 1, 2019    2017          TV-MA   86 min     Documentaries, International Movies             This documentary paints a candid picture of Australian street artist Anthony Lister as he navigates his burgeoning career and personal hardships.           1
# TV Show  You                                           Lee Toland Krieger   Penn Badgley, Elizabeth Lail, Shay Mitchell, John Stamos, Luca Padovan, Zach Cherry                                                                             United States   December 26, 2019   2019          TV-MA   2 Seasons  Crime TV Shows, Romantic TV Shows, TV Dramas    Obsessed with an aspiring writer, a charming bookstore manager goes to extreme measures to insert himself into her life.                                    1
# Length: 5332, dtype: int64

# %%
# return containing counts of unique values at type field
df["type"].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
# create type value count as pie plot
Type = df.groupby("type").size()
Type.plot(kind = "pie", title = "Distribution By Type", ylabel = "", figsize = [10,6], shadow = True,
          autopct = lambda p:"{:.2f}%({:.0f})".format(p,(p/100)*Type.sum()))

# save pie plot as png
plt.savefig(fname = "graphic1.png", transparent = True)

# show pie plot
plt.show()

# %% [raw]
# ! we can see clearly that movie count more than tv show count
# ! observation 1: Netflix has hosted movies more than tv show

# %% [markdown]
# ### Data Summarization

# %%
# describe categorical data by type
df.groupby("type").describe(include = "O").T
# Out:
# type                                                            Movie  \
# title       count                                                6131
#             unique                                               6131
#             top                                  Dick Johnson Is Dead
#             freq                                                    1
# director    count                                                5943
#             unique                                               4354
#             top                                         Rajiv Chilaka
#             freq                                                   19
# cast        count                                                5656
#             unique                                               5445
#             top     Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...
#             freq                                                   13
# country     count                                                5691
#             unique                                                651
#             top                                         United States
#             freq                                                 2058
# date_added  count                                                6131
#             unique                                               1533
#             top                                       January 1, 2020
#             freq                                                   97
# rating      count                                                6129
#             unique                                                 17
#             top                                                 TV-MA
#             freq                                                 2062
# duration    count                                                6128
#             unique                                                205
#             top                                                90 min
#             freq                                                  152
# listed_in   count                                                6131
#             unique                                                278
#             top                          Dramas, International Movies
#             freq                                                  362
# description count                                                6131
#             unique                                               6105
#             top     Paranormal activity at a lush, abandoned prope...
#             freq                                                    4
#
# type                                                          TV Show
# title       count                                                2676
#             unique                                               2676
#             top                                         Blood & Water
#             freq                                                    1
# director    count                                                 230
#             unique                                                222
#             top                                   Alastair Fothergill
#             freq                                                    3
# cast        count                                                2326
#             unique                                               2283
#             top                                    David Attenborough
#             freq                                                   14
# country     count                                                2285
#             unique                                                196
#             top                                         United States
#             freq                                                  760
# date_added  count                                                2666
#             unique                                               1051
#             top                                          July 6, 2021
#             freq                                                   31
# rating      count                                                2674
#             unique                                                  9
#             top                                                 TV-MA
#             freq                                                 1145
# duration    count                                                2676
#             unique                                                 15
#             top                                              1 Season
#             freq                                                 1793
# listed_in   count                                                2676
#             unique                                                236
#             top                                              Kids' TV
#             freq                                                  220
# description count                                                2676
#             unique                                               2672
#             top     This educational series for tiny tots features...
#             freq                                                    2

# %% [raw]
# ! observation 2:
# ! there are repetitive record according to cast and director fields
# ! united states produces the most content
# ! the most movie added in January 1, 2020 and the most tv show added July 6, 2021
# ! most of the content on Netflix seems to be for adults

# %% [markdown]
# ## <span class="burk">Data Cleaning and Imputation</span>

# %% [markdown]
# ### Addressing with Missing Data

# %%
# show the sum of missing records by field
df.isnull().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# how many of the null records are expendable?
threshold = len(df)*0.05
threshold
# Out:
# 440.35

# %%
# fill in fields director, cast and country with acceptable data
values = {"director": "No Director", "cast": "No Cast", "country": "Not Specify"}
df.fillna(value = values, inplace = True)

# %%
# delete the remaining missing rows
df = df.dropna()

# %%
# check again for null record
df.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
# count the data in column description
df["description"].value_counts()
# Out:
# Paranormal activity at a lush, abandoned property alarms a group eager to redevelop the site, but the eerie events may not be as unearthly as they think.    4
# Multiple women report their husbands as missing but when it appears they are looking for the same man, a police officer traces their cryptic connection.     3
# Challenged to compose 100 songs before he can marry the girl he loves, a tortured but passionate singer-songwriter embarks on a poignant musical journey.    3
# A surly septuagenarian gets another chance at her 20s after having her photo snapped at a studio that magically takes 50 years off her life.                 3
# As a series of murders hit close to home, a video game designer with post-traumatic stress must confront her demons, or risk becoming their victim.          2
#                                                                                                                                                             ..
# Exhausted with his mother’s failed attempts at setting him up with women, Ican hires an ideal partner from a matchmaking app.                                1
# Director Alfonso Cuarón reflects on the childhood memories, period details and creative choices that shaped his Academy Award-winning film "ROMA."           1
# After spearheading an ill-fated bank robbery, a man must get his mentally challenged younger brother out of jail while eluding his own capture.              1
# In this interactive special, Harold and George need your decision-making skills to stop Krupp from blowing their beloved treehouse to smithereens.           1
# A scrappy but poor boy worms his way into a tycoon's dysfunctional family, while facing his fear of music and the truth about his past.                      1
# Name: description, Length: 8758, dtype: int64

# %%
# show repetitive data in field description
df[df["description"].duplicated()]
# Out:
#             type                                              title  \
# show_id
# s80        Movie                            Tughlaq Durbar (Telugu)
# s238       Movie                                    Boomika (Hindi)
# s239       Movie                                Boomika (Malayalam)
# s240       Movie                                   Boomika (Telugu)
# s852       Movie                                   99 Songs (Tamil)
# s853       Movie                                  99 Songs (Telugu)
# s1654      Movie                                        Andhakaaram
# s1987      Movie                                   Nee Enge En Anbe
# s2336      Movie                                     Seven (Telugu)
# s2874      Movie                            Ala Vaikunthapurramuloo
# s3394    TV Show  ChuChu TV Kids Songs, Learning Videos & Bedtim...
# s3494      Movie                                   Oh! Baby (Tamil)
# s3517      Movie                                           Oh! Baby
# s3570      Movie                          Game Over (Tamil Version)
# s3940      Movie                                              Petta
# s4062      Movie                Sarvam Thaala Mayam (Tamil Version)
# s5965    TV Show                                             Feb-09
# s5966      Movie                                             22-Jul
# s5967      Movie                                             15-Aug
# s6025    TV Show                                          7 (Seven)
# s6450      Movie                                    Chashme Buddoor
# s6530      Movie                                      Consequences
# s6706      Movie                               Esperando La Carroza
# s7023      Movie                               Hum Saath-Saath Hain
# s7090      Movie  Inuyasha the Movie - La spada del dominatore d...
# s7091      Movie  InuYasha: The Movie 2: The Castle Beyond the L...
# s7560      Movie                    Naruto Shippuden : Blood Prison
# s7650    TV Show                                       Ollie & Moon
# s8023    TV Show                           Sin Senos sí Hay Paraíso
# s8053      Movie          Solo: A Star Wars Story (Spanish Version)
# s8174    TV Show                                          Thackeray
# s8361      Movie                                  The Incredibles 2
#
#                          director  \
# show_id
# s80      Delhiprasad Deenadayalan
# s238          Rathindran R Prasad
# s239          Rathindran R Prasad
# s240          Rathindran R Prasad
# s852                  No Director
# s853                  No Director
# s1654                V Vignarajan
# s1987              Sekhar Kammula
# s2336                 No Director
# s2874          Trivikram Srinivas
# s3394                 No Director
# s3494         B. V. Nandini Reddy
# s3517         B. V. Nandini Reddy
# s3570            Ashwin Saravanan
# s3940            Karthik Subbaraj
# s4062                 Rajiv Menon
# s5965                 No Director
# s5966             Paul Greengrass
# s5967          Swapnaneel Jayakar
# s6025                 Nizar Shafi
# s6450                David Dhawan
# s6530                Ozan Açıktan
# s6706             Alejandro Doria
# s7023          Sooraj R. Barjatya
# s7090           Toshiya Shinohara
# s7091           Toshiya Shinohara
# s7560             Masahiko Murata
# s7650                 No Director
# s8023                 No Director
# s8053                  Ron Howard
# s8174                 No Director
# s8361                   Brad Bird
#
#                                                       cast  \
# show_id
# s80             Vijay Sethupathi, Parthiban, Raashi Khanna
# s238     Aishwarya Rajesh, Vidhu, Surya Ganapathy, Madh...
# s239     Aishwarya Rajesh, Vidhu, Surya Ganapathy, Madh...
# s240     Aishwarya Rajesh, Vidhu, Surya Ganapathy, Madh...
# s852                                               No Cast
# s853                                               No Cast
# s1654    Vinoth Kishan, Arjun Das, Pooja Ramachandran, ...
# s1987    Nayantara, Vaibhav Reddy, Pasupathy, Harshvard...
# s2336                                              No Cast
# s2874    Allu Arjun, Pooja Hegde, Tabu, Sushanth, Nivet...
# s3394                                              No Cast
# s3494    Samantha Ruth Prabhu, Lakshmi, Rajendraprasad,...
# s3517    Samantha Ruth Prabhu, Lakshmi, Rajendraprasad,...
# s3570    Taapsee Pannu, Vinodhini, Parvathi T, Ramya Su...
# s3940    Rajnikanth, Vijay Sethupathi, M. Sasikumar, Na...
# s4062    G.V. Prakash Kumar, Nedumudi Venu, Aparna Bala...
# s5965    Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...
# s5966    Anders Danielsen Lie, Jon Øigarden, Jonas Stra...
# s5967    Rahul Pethe, Mrunmayee Deshpande, Adinath Koth...
# s6025    Rahman, Havish, Regina Cassandra, Nandita Swet...
# s6450    Ali Zafar, Siddharth, Divyendu Sharma, Tapsee ...
# s6530    Nehir Erdoğan, Tardu Flordun, İlker Kaleli, Se...
# s6706    Luis Brandoni, China Zorrilla, Antonio Gasalla...
# s7023    Salman Khan, Karisma Kapoor, Saif Ali Khan, Ta...
# s7090    Kappei Yamaguchi, Satsuki Yukino, Koji Tsujita...
# s7091    Kappei Yamaguchi, Satsuki Yukino, Koji Tsujita...
# s7560    Junko Takeuchi, Chie Nakamura, Rikiya Koyama, ...
# s7650                         Mattea Conforti, Kobi Frumer
# s8023    Majida Issa, Fabián Ríos, Catherine Siachoque,...
# s8053    Alden Ehrenreich, Woody Harrelson, Emilia Clar...
# s8174                                              No Cast
# s8361    Craig T. Nelson, Holly Hunter, Samuel L. Jacks...
#
#                                 country          date_added  release_year  \
# show_id
# s80                         Not Specify  September 11, 2021          2021
# s238                        Not Specify     August 23, 2021          2021
# s239                        Not Specify     August 23, 2021          2021
# s240                        Not Specify     August 23, 2021          2021
# s852                        Not Specify        May 21, 2021          2021
# s853                        Not Specify        May 21, 2021          2021
# s1654                             India   November 24, 2020          2020
# s1987                       Not Specify  September 17, 2020          2014
# s2336                       Not Specify       June 26, 2020          2019
# s2874                             India   February 27, 2020          2020
# s3394                       Not Specify    October 18, 2019          2019
# s3494                       Not Specify  September 25, 2019          2019
# s3517                             India  September 14, 2019          2019
# s3570                     India, Turkey     August 21, 2019          2019
# s3940                             India       April 5, 2019          2019
# s4062                       Not Specify       March 1, 2019          2018
# s5965                       Not Specify      March 20, 2019          2018
# s5966    Norway, Iceland, United States    October 10, 2018          2018
# s5967                             India      March 29, 2019          2019
# s6025                             India       July 30, 2019          2019
# s6450                             India         May 1, 2017          2013
# s6530                            Turkey    October 25, 2019          2014
# s6706                         Argentina       July 15, 2018          1985
# s7023                             India     January 1, 2018          1999
# s7090                             Japan   September 1, 2017          2003
# s7091                             Japan   September 1, 2017          2002
# s7560                             Japan   September 1, 2017          2011
# s7650                            France      March 28, 2018          2018
# s8023           United States, Colombia    January 11, 2019          2018
# s8053                     United States     January 9, 2019          2018
# s8174                             India        May 25, 2019          2019
# s8361                     United States    January 30, 2019          2018
#
#         rating   duration                                          listed_in  \
# show_id
# s80      TV-14    145 min             Comedies, Dramas, International Movies
# s238     TV-14    122 min     Horror Movies, International Movies, Thrillers
# s239     TV-14    122 min     Horror Movies, International Movies, Thrillers
# s240     TV-14    122 min     Horror Movies, International Movies, Thrillers
# s852     TV-14    131 min     Dramas, International Movies, Music & Musicals
# s853     TV-14    131 min     Dramas, International Movies, Music & Musicals
# s1654    TV-14    171 min     Horror Movies, International Movies, Thrillers
# s1987    TV-14    137 min                    International Movies, Thrillers
# s2336    TV-14    116 min      Dramas, International Movies, Romantic Movies
# s2874    TV-14    162 min               Action & Adventure, Comedies, Dramas
# s3394     TV-Y   1 Season                                           Kids' TV
# s3494    TV-14    146 min   Comedies, International Movies, Music & Musicals
# s3517    TV-14    157 min   Comedies, International Movies, Music & Musicals
# s3570    TV-MA     98 min     Horror Movies, International Movies, Thrillers
# s3940    TV-14    170 min               Action & Adventure, Comedies, Dramas
# s4062    TV-14    131 min     Dramas, International Movies, Music & Musicals
# s5965    TV-14   1 Season                  International TV Shows, TV Dramas
# s5966        R    144 min                                  Dramas, Thrillers
# s5967    TV-14    124 min               Comedies, Dramas, Independent Movies
# s6025    TV-14   1 Season                                           TV Shows
# s6450    TV-PG    121 min   Comedies, International Movies, Music & Musicals
# s6530    TV-MA    106 min            Dramas, International Movies, Thrillers
# s6706       NR     95 min        Comedies, Cult Movies, International Movies
# s7023     TV-G    176 min     Dramas, International Movies, Music & Musicals
# s7090    TV-14     99 min  Action & Adventure, Anime Features, Internatio...
# s7091    TV-14     99 min  Action & Adventure, Anime Features, Internatio...
# s7560    TV-14    102 min  Action & Adventure, Anime Features, Internatio...
# s7650     TV-Y   1 Season                                           Kids' TV
# s8023    TV-MA  3 Seasons  International TV Shows, Spanish-Language TV Sh...
# s8053    PG-13    135 min  Action & Adventure, Children & Family Movies, ...
# s8174    TV-MA   1 Season                                           TV Shows
# s8361       PG    118 min                 Children & Family Movies, Comedies
#
#                                                description
# show_id
# s80      A budding politician has devious plans to rise...
# s238     Paranormal activity at a lush, abandoned prope...
# s239     Paranormal activity at a lush, abandoned prope...
# s240     Paranormal activity at a lush, abandoned prope...
# s852     Challenged to compose 100 songs before he can ...
# s853     Challenged to compose 100 songs before he can ...
# s1654    As a blind librarian, dispirited cricketer and...
# s1987    As a woman scours Hyderabad for her missing hu...
# s2336    Multiple women report their husbands as missin...
# s2874    After growing up enduring criticism from his f...
# s3394    This educational series for tiny tots features...
# s3494    A surly septuagenarian gets another chance at ...
# s3517    A surly septuagenarian gets another chance at ...
# s3570    As a series of murders hit close to home, a vi...
# s3940    An affable, newly appointed college warden pro...
# s4062    An aspiring musician battles age-old caste div...
# s5965    As a psychology professor faces Alzheimer's, h...
# s5966    After devastating terror attacks in Norway, a ...
# s5967    On India's Independence Day, a zany mishap in ...
# s6025    Multiple women report their husbands as missin...
# s6450    When pretty new neighbor Seema falls for their...
# s6530    Secrets bubble to the surface after a sensual ...
# s6706    Cora has three sons and a daughter and she´s a...
# s7023    A scheming matriarch plots to cut off her disa...
# s7090    The Great Dog Demon beaqueathed one of the Thr...
# s7091    With their biggest foe seemingly defeated, Inu...
# s7560    Mistakenly accused of an attack on the Fourth ...
# s7650    Two quirky cats, Ollie and Moon, and their fri...
# s8023    Born into a small town controlled by the mafia...
# s8053    A young Han Solo tries to settle an old score ...
# s8174    From controversial cartoonist to powerful Mumb...
# s8361    When Elastigirl gets recruited for a high-prof...

# %%
# finding how many repeating data in a field description
df["description"].duplicated().sum()
# Out:
# 32

# %%
# delete repeating data in a field description
df.drop_duplicates(subset= "description", inplace = True)

# %% [markdown]
# ### Converting and Analyzing Categorical Data

# %%
# take a look at second record to cast field
df["cast"][1]
# Out:
# 'Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng'

# %%
# try your luck to get the first 4 players
df["cast"].values[0:5][1].split(",")[0:]
# Out:
# ['Ama Qamata',
#  ' Khosi Ngema',
#  ' Gail Mabalane',
#  ' Thabang Molaba',
#  ' Dillon Windvogel',
#  ' Natasha Thahane',
#  ' Arno Greeff',
#  ' Xolile Tshabalala',
#  ' Getmore Sithole',
#  ' Cindy Mahlangu',
#  ' Ryle De Morny',
#  ' Greteli Fincham',
#  ' Sello Maake Ka-Ncube',
#  ' Odwa Gwanya',
#  ' Mekaila Mathys',
#  ' Sandi Schultz',
#  ' Duane Williams',
#  ' Shamilla Miller',
#  ' Patrick Mofokeng']

# %%
# now let's take the first 4 players in each row of the whole field
for _ in range(0,len(df)):
    if df["cast"][_] == "No Cast":
        continue
    else:
        df["cast"][_] = df["cast"].values[0:len(df)][_].split(", ")[0:]

# %%
# delete space and comma in field country
df["country"] = df["country"].str.rstrip(", ")
df["country"] = df["country"].str.lstrip(", ")

# %%
# derive a new field called genre based on the records in field listed_in
genre_list = ["Children", "Documentaries", "Stand-Up"]
for genre in genre_list:
    df.loc[df["listed_in"].str.contains(genre, case=False), "genre"] = genre

# %%
# fill missing value in field genre with "other" 
df["genre"].fillna("Other", inplace=True)

# %%
# derive a new field called rating_age based on the records in field rating
mapping = {"TV-Y":"Kids","TV-G":"Kids","G":"Kids", 
           "TV-PG":"Older Kids","TV-Y7-FV":"Older Kids","TV-Y7":"Older Kids","PG":"Older Kids",
           "TV-14":"Teen", "PG-13":"Teen", 
           "TV-MA":"Adults","R":"Adults","NC-17":"Adults",
           "NR":"Not Rated","UR":"Not Rated"}
df["rating_age"] = df["rating"].replace(mapping)

# %% [raw]
# ! now we have more acceptable and actionable categorical data

# %% [markdown]
# ### Working with Numeric Data

# %%
# remove unwanted characters from field duration
df["duration"] = df["duration"].str.strip("Sseaonmin ")

# %%
# Convert the data type of field duration to integer
df["duration"] = pd.to_numeric(df["duration"])

# %%
# Convert the data type of field date_added to datetime
df["date_added"] = pd.to_datetime(df["date_added"])

# %%
# derive a new field called added_year based on the field date_added
df["added_year"] = df.date_added.dt.year

# %%
# create new field called production to see which production it belongs to
# if the year of publication and the year of addition to Netflix are equal, we assume that this content belongs to Netflix
# our assumption looks correct when we check a few random sample. but it is important that this assumption may wrong
df["production"] = df.apply(lambda x: "N" if x["added_year"] == x["release_year"] else "O", axis=1)

# %% [raw]
# ! now we have more acceptable and actionable numeric data

# %% [markdown]
# ### Handling Outliers

# %% [raw]
# ! since the duration field of TV Show is season and the duration field of movies is minutes,
# ! we will examine them as two different dataframes.

# %%
# create dataframes containing only movie records
netflix_movies_only = df[df["type"] == "Movie"]

# %%
# create dataframes containing only TV Show records
netflix_tvshow_only = df[df["type"] == "TV Show"]

# %%
# create a function to display outlier
def extract_outliers_from_boxplot(array):
    # Get IQR
    q1 = np.quantile(array, 0.25)
    q3 = np.quantile(array, 0.75)
    med = np.median(array)
    
    # finding the iqr region
    iqr = q3-q1
    
    # iqr = stats.iqr(array)
    # finding upper and lower whiskers
    upper_bound = q3+(1.5*iqr)
    lower_bound = q1-(1.5*iqr)
    
    outliers = array[(array <= lower_bound) | (array >= upper_bound)]
    print("Outliers within the box plot are:")
    return outliers

# %%
# using function to display possible outliers for movies
extract_outliers_from_boxplot(netflix_movies_only["duration"])
# Out:
# Outliers within the box plot are:
# show_id
# s23      161
# s25      166
# s46       23
# s72       13
# s74      182
#         ...
# s8764     45
# s8765    191
# s8771    171
# s8789    157
# s8803    158
# Name: duration, Length: 444, dtype: int64

# %%
# demonstrate possible outliers for movie with boxplot
sns.boxplot(netflix_movies_only["duration"])
# Out:
# <Axes: >

# %% [raw]
# ! this graph above the line shows that movies with more than 160 minutes and less than 50 minutes as outliers
# ! movies can last more than 160 minutes
# ! usually movies last longer than 60 minutes, so we should check movies that last less than 60 minutes

# %%
# demonstrate possible outliers for movie with hist
netflix_movies_only["duration"].hist(bins = 50)
# Out:
# <Axes: >

# %%
# demonstrate possible outliers for movie with displot
sns.displot(netflix_movies_only["duration"])

# %% [raw]
# ! observation 3: this graphs above the line looks like it has a normal distribution (Gauss Distribution)
# ! the normal distribution represents the mean, mode and median values being close to each other
# ! and we can clearly see that there is more aggregation in the number of movies less than 60 minutes

# %% [raw]
# ! Another way to test the normal distribution is to look at the kurtosis and skewness coefficients

# %%
# netflix_movies_only skewness
netflix_movies_only["duration"].skew()
# Out:
# 0.2039406934220291

# %%
# netflix_movies_only kurtosis
netflix_movies_only["duration"].kurt()
# Out:
# 2.3278196614227458

# %% [raw]
# ! movies coefficient of skewness is 0.20 and coefficient of kurtosis is 2.32
# ! which means it's slightly skewed to the left and pointed.

# %%
# using function to display possible outliers for tvshow
extract_outliers_from_boxplot(netflix_tvshow_only["duration"])
# Out:
# Outliers within the box plot are:
# show_id
# s9       9
# s16      4
# s22      5
# s56      6
# s66      6
#         ..
# s8542    4
# s8558    7
# s8654    4
# s8711    8
# s8727    5
# Name: duration, Length: 254, dtype: int64

# %%
# demonstrate possible outliers for movies with hist
sns.boxplot(netflix_tvshow_only["duration"])
# Out:
# <Axes: >

# %%
# demonstrate possible outliers for tvshow with hist
netflix_tvshow_only["duration"].hist(bins = 50)
# Out:
# <Axes: >

# %% [raw]
# ! we cannot reach a correct conclusion by looking at the graphs above the line beacuse of tvshow duration is season
# ! lets find out tvshow median and mode

# %%
# finding the most recurring value
netflix_tvshow_only["duration"].mode()
# Out:
# 0    1
# Name: duration, dtype: int64

# %%
# finding the value in the middle
netflix_tvshow_only["duration"].median()
# Out:
# 1.0

# %% [raw]
# ! observation 4: according to the statistics above the line tv show duration last proximately 1 season

# %% [markdown]
# ## <span class="burk">Relationship in Data</span>

# %% [markdown]
# ### Patterns Over Time

# %% [markdown]
# ### Correlation

# %%
# finding correlation among release_date, 
# added_year and duration for movies
corr_matrix_movies = netflix_movies_only.corr()
corr_matrix_movies
# Out:
#               release_year  duration  added_year
# release_year         1.000    -0.209       0.037
# duration            -0.209     1.000       0.123
# added_year           0.037     0.123       1.000

# %%
# create heatmap for correlation among release_date, added_year and duration
sns.heatmap(corr_matrix_movies,  annot=True)
plt.show()

# %% [raw]
# ! there is a positive and weak correlation between release_year and added_year
# ! there is a negative and weak correlation between release_year and duration
# ! there is a positive and weak correlation between added_year and duration
# ! observation 5: release_year and added_year increase and decrease in the same direction,
# ! while release_year and duration increase and decrease in the opposite direction

# %%
# finding correlation among release_date, 
corr_matrix_tv = netflix_tvshow_only.corr()
corr_matrix_tv
# Out:
#               release_year  duration  added_year
# release_year         1.000    -0.081       0.388
# duration            -0.081     1.000       0.042
# added_year           0.388     0.042       1.000

# %%
# create heatmap for correlation among release_date, added_year and duration
sns.heatmap(corr_matrix_tv,  annot = True)
plt.show()

# %% [raw]
# ! there is a positive and weak correlation between release_year and added_year
# ! there is a negative and weak correlation between release_year and duration
# ! there is a positive and weak correlation between added_year and duration
# ! observation 6: release_year and added_year increase and decrease in the same direction,
# ! while release_year and duration increase and decrease in the opposite direction

# %%
# let's create a scatter plot showing the relationship between release_year and duration
plt.scatter("release_year", "duration", data = netflix_movies_only)
plt.title("Relationship Between Release Year and Duration", fontweight = 'bold', fontsize = 15)
plt.ylabel("Duration", fontweight = 'bold', fontsize = 15)
plt.show()

# %%
# let's create a regplot showing the relationship between release_year and duration
sns.regplot(x = "release_year", y = "duration", data = netflix_movies_only)
plt.title("Relationship Between Release Year and Duration", fontweight = 'bold', fontsize = 15)
plt.ylabel("Duration", fontweight = 'bold', fontsize = 15)
plt.show()

# %% [raw]
# ! observation 7: according to the scatter plots above; the duration of the movies decreases according to the years

# %%
# finding correlation among release_date, added_year and duration for movies added after 2016
corr_matrix_2016 = netflix_movies_2016.corr()
corr_matrix_2016
# Out:
#               release_year  added_year  duration
# release_year         1.000       0.089    -0.255
# added_year           0.089       1.000     0.024
# duration            -0.255       0.024     1.000

# %%
# create heatmap for correlation among release_date, added_year and duration for movies added after 2016
sns.heatmap(corr_matrix_2016,  annot = True)
plt.show()

# %%
# let's create a scatter plot showing the relationship between release_year and duration for movies added after 2016
plt.scatter("release_year", "duration", data = netflix_movies_2016)
plt.show()

# %%
# let's create a scatter plot showing the relationship between added_year and duration for movies added after 2016
plt.scatter("added_year", "duration", data = netflix_movies_2016)
plt.show()

# %% [markdown]
# ### Factor Relationships and Distributions

# %%
# investigate and subset the Netflix data by "Movie" type, 
# keeping only the columns "title", "country", "genre", "release_year", "duration"
# saving this into a new DataFrame called netflix_movies
netflix_movies = netflix_movies_only[["title","country","genre","release_year","duration"]]

# %%
# filter netflix_movies to find the movies that are shorter than 60 minutes
short_movies = netflix_movies[netflix_movies["duration"] < 60]

# %% [raw]
# ! inspect the result to find possible contributing factors

# %%
# finding duration value count by country
short_movies.groupby("country")["duration"].value_counts()
# Out:
# country                        duration
# Argentina                      49          1
#                                51          1
#                                58          1
# Australia                      23          1
#                                25          1
#                                           ..
# United States, Japan           59          2
# United States, Mexico          25          1
#                                30          1
#                                38          1
# United States, United Kingdom  55          1
# Name: duration, Length: 193, dtype: int64

# %%
# finding duration value count by genre
short_movies.groupby("genre")["duration"].value_counts()
# Out:
# genre     duration
# Children  46          17
#           24          14
#           23           9
#           22           8
#           25           8
#                       ..
# Stand-Up  28           1
#           31           1
#           42           1
#           45           1
#           48           1
# Name: duration, Length: 138, dtype: int64

# %%
# finding duration value count by release_year
short_movies.groupby("release_year")["duration"].value_counts()
# Out:
# release_year  duration
# 1942          18          1
#               52          1
# 1943          45          1
# 1944          40          2
# 1945          32          1
#                          ..
# 2021          49          1
#               52          1
#               54          1
#               55          1
#               59          1
# Name: duration, Length: 263, dtype: int64

# %%
# finding duration mean, min, max by release year and demonstrate as a plot
short_movies.groupby("release_year")["duration"].agg(["mean","min","max"]).plot(kind = "bar", ylabel = "Duration", 
                                                                                xlabel = "Release Year")
# Out:
# <Axes: xlabel='Release Year', ylabel='Duration'>

# %% [raw]
# ! observation 8: according to the release_year, minimum duration of the movies decreases
# ! while maximum and average durations increase

# %%
# finding duration mean, min, max and count by country
short_movies.groupby("country")["duration"].agg(["mean","min","max","count"])
# Out:
#                                                      mean  min  max  count
# country
# Argentina                                          52.667   49   58      3
# Australia                                          24.000   23   25      2
# Australia, Canada                                  51.000   51   51      1
# Brazil                                             49.667   44   59      3
# Canada                                             35.200   24   53     20
# Canada, United Kingdom                             51.000   51   51      1
# Canada, United States                              19.000   19   19      1
# Colombia                                           59.000   59   59      1
# Czech Republic, France                             52.000   52   52      1
# Denmark, China                                     44.000   44   44      1
# Egypt                                              15.000   15   15      1
# France                                             54.000   52   57      6
# France, South Korea, Japan                         22.000   22   22      1
# Georgia                                            24.000   24   24      1
# Germany                                            43.667   21   58      3
# Iceland                                            54.000   54   54      1
# India                                              47.111   29   59      9
# Ireland, Canada                                    30.000   30   30      1
# Ireland, United States, France                     53.000   53   53      1
# Israel                                             55.000   55   55      1
# Italy                                              49.000   45   53      2
# Japan                                              40.125    5   58      8
# Japan, United States                               53.000   53   53      1
# Lebanon, Syria                                     13.000   13   13      1
# Mexico                                             49.273   28   57     11
# Mexico, Argentina                                  51.000   51   51      1
# Mexico, United States                              28.000   28   28      1
# Namibia                                            29.000   29   29      1
# Netherlands                                        34.500   12   57      2
# Nigeria                                            21.000   21   21      1
# Norway                                             58.000   58   58      1
# Not Specify                                        38.148   11   59     88
# Pakistan, United States                            16.000   16   16      1
# Poland                                             33.000   33   33      1
# South Africa                                       30.000   30   30      1
# South Korea                                        54.000   54   54      1
# Spain                                              41.000   25   57      2
# Sweden, United States                              40.000   40   40      1
# United Kingdom                                     47.163   15   59     43
# United Kingdom, Germany                            26.000   26   26      1
# United Kingdom, Kenya                              28.000   28   28      1
# United Kingdom, United States, Spain, Germany, ... 49.500   47   52      2
# United States                                      41.921    3   59    216
# United States, Canada                              34.000   24   44      2
# United States, France                              49.000   49   49      1
# United States, India                               45.000   45   45      1
# United States, Japan                               59.000   59   59      2
# United States, Mexico                              31.000   25   38      3
# United States, United Kingdom                      55.000   55   55      1

# %%
# finding duration mean, min, max and count by genre
short_movies.groupby("genre")["duration"].agg(["mean","min","max","count"])
# Out:
#                 mean  min  max  count
# genre
# Children      33.974    3   59    116
# Documentaries 44.593   10   59    177
# Other         36.101    5   59     89
# Stand-Up      53.053   28   59     75

# %% [raw]
# ! we found the average duration, minimum duration, maximum duration and total content value of Netflix movies
# ! shorter than 60 minutes by genre
# ! observation 9: Netflix keeps the time under 60 minutes while submitting content for specific genre

# %%
# top 10 countries producing less than 60 minutes of movie content
short_movies["country"].value_counts().head(10).plot(kind = "bar", title = "Top 10 Country", ylabel = "Number Of Content")
# Out:
# <Axes: title={'center': 'Top 10 Country'}, ylabel='Number Of Content'>

# %%
# Using a for loop, assign colors of your choice to four genre groups from netflix_movies, 
# ("Children", "Documentaries", "Stand-Up", and "Other") saving them to a colors list, 
# and use this to initialize a figure object and create a scatter plot for movie duration by release 
# year using the labels "Release year" for the x-axis,
# "Duration (min)" for the y-axis, and the title "Movie Duration by Year of Release"

# define an empty list
colors = []

# iterate over rows of short_movies
for x, row in short_movies.iterrows() :
    if row["genre"] == "Children":
        colors.append("red")
    elif row["genre"] == "Documentaries":
        colors.append("blue")
    elif row["genre"] == "Stand-Up":
        colors.append("green")
    else:
        colors.append("yellow")
        
# inspect the first 5 values in list        
colors[:5]
# Out:
# ['blue', 'red', 'red', 'red', 'yellow']

# %%
# create a scatter plot of duration versus release_year
plt.scatter(short_movies.release_year, short_movies.duration, color=colors)

# create a title and axis labels
plt.title("Movie Duration By Year Of Release", fontweight ='bold', fontsize = 15)
plt.xlabel("Release year", fontweight = 'bold', fontsize = 15)
plt.ylabel("Duration (min)", fontweight = 'bold', fontsize = 15)

# save scatter plot as png
plt.savefig(fname = "grafic2.png")

# show the plot
plt.show()

# %% [raw]
# ! observation 10: particularly in recent years, there has been an increase in the number of content and genres less than 60 min.
# ! there has been visibly decrease, movies minimum duration

# %%
# create a line of duration versus release_year
sns.lineplot(x = "release_year", y = "duration", data = short_movies, ci = None, hue = colors)
plt.title("Movie Duration By Year Of Release", fontweight = "bold", fontsize = 15)
plt.xlabel("Release year", fontweight = "bold", fontsize = 15)
plt.ylabel("Duration (min)", fontweight = "bold", fontsize = 15)
plt.show()

# %% [raw]
# ! it's too complicated, let's try it with relplot

# %%
# create a relplot of duration versus release_year
sns.relplot(x = "release_year", y = "duration", data = short_movies, ci = None, hue = colors, kind = "line", height = 4, aspect = 6)
plt.title("Movie Duration By Year Of Release", fontweight = "bold", fontsize = 15)
plt.xlabel("Release year", fontweight = "bold", fontsize = 15)
plt.ylabel("Duration (min)", fontweight = "bold", fontsize = 15)

# save relplot as png
plt.savefig(fname="grafic3.png")

# show the plot
plt.show()

# %% [raw]
# ! according to relplot above the line; there has been a decrease in the duration of the children and documentries
# ! there has been an increase in the duration of the stand up

# %% [markdown]
# ## <span class="burk">Turning Exploratory Analysis into Action</span>

# %% [markdown]
# ### Considerations for Categorical Data

# %%
#Considerations-for-Categorical-Data# Cross-tabulate country and genre
pd.crosstab(short_movies["country"], short_movies["genre"])
# Out:
# genre                                               Children  Documentaries  \
# country
# Argentina                                                  0              1
# Australia                                                  2              0
# Australia, Canada                                          1              0
# Brazil                                                     0              0
# Canada                                                    14              2
# Canada, United Kingdom                                     0              1
# Canada, United States                                      0              1
# Colombia                                                   0              0
# Czech Republic, France                                     0              1
# Denmark, China                                             1              0
# Egypt                                                      0              0
# France                                                     0              4
# France, South Korea, Japan                                 0              0
# Georgia                                                    0              1
# Germany                                                    0              2
# Iceland                                                    0              0
# India                                                      0              7
# Ireland, Canada                                            1              0
# Ireland, United States, France                             0              1
# Israel                                                     0              1
# Italy                                                      0              1
# Japan                                                      1              0
# Japan, United States                                       0              1
# Lebanon, Syria                                             0              0
# Mexico                                                     0              1
# Mexico, Argentina                                          0              0
# Mexico, United States                                      0              1
# Namibia                                                    0              0
# Netherlands                                                0              0
# Nigeria                                                    0              1
# Norway                                                     0              1
# Not Specify                                               30             26
# Pakistan, United States                                    1              0
# Poland                                                     0              0
# South Africa                                               0              0
# South Korea                                                0              0
# Spain                                                      0              1
# Sweden, United States                                      0              1
# United Kingdom                                             3             29
# United Kingdom, Germany                                    1              0
# United Kingdom, Kenya                                      0              0
# United Kingdom, United States, Spain, Germany, ...         0              0
# United States                                             57             86
# United States, Canada                                      2              0
# United States, France                                      0              1
# United States, India                                       1              0
# United States, Japan                                       1              1
# United States, Mexico                                      0              3
# United States, United Kingdom                              0              1
#
# genre                                               Other  Stand-Up
# country
# Argentina                                               0         2
# Australia                                               0         0
# Australia, Canada                                       0         0
# Brazil                                                  2         1
# Canada                                                  3         1
# Canada, United Kingdom                                  0         0
# Canada, United States                                   0         0
# Colombia                                                0         1
# Czech Republic, France                                  0         0
# Denmark, China                                          0         0
# Egypt                                                   1         0
# France                                                  0         2
# France, South Korea, Japan                              1         0
# Georgia                                                 0         0
# Germany                                                 0         1
# Iceland                                                 0         1
# India                                                   1         1
# Ireland, Canada                                         0         0
# Ireland, United States, France                          0         0
# Israel                                                  0         0
# Italy                                                   0         1
# Japan                                                   7         0
# Japan, United States                                    0         0
# Lebanon, Syria                                          1         0
# Mexico                                                  0        10
# Mexico, Argentina                                       1         0
# Mexico, United States                                   0         0
# Namibia                                                 1         0
# Netherlands                                             2         0
# Nigeria                                                 0         0
# Norway                                                  0         0
# Not Specify                                            26         6
# Pakistan, United States                                 0         0
# Poland                                                  1         0
# South Africa                                            1         0
# South Korea                                             0         1
# Spain                                                   1         0
# Sweden, United States                                   0         0
# United Kingdom                                          5         6
# United Kingdom, Germany                                 0         0
# United Kingdom, Kenya                                   1         0
# United Kingdom, United States, Spain, Germany, ...      2         0
# United States                                          32        41
# United States, Canada                                   0         0
# United States, France                                   0         0
# United States, India                                    0         0
# United States, Japan                                    0         0
# United States, Mexico                                   0         0
# United States, United Kingdom                           0         0

# %% [raw]
# ! we can see the number of countries by genre of content
# ! observation 11: united states has the most genres and the most content

# %%
# average duration of genres by year
(pd.crosstab(short_movies["release_year"], short_movies["genre"], values = short_movies["duration"],
             aggfunc = "mean")).fillna("0")
# Out:
# genre        Children Documentaries  Other Stand-Up
# release_year
# 1942                0        35.000      0        0
# 1943                0        45.000      0        0
# 1944                0        40.000      0        0
# 1945                0        45.500      0        0
# 1946                0        58.000      0        0
# 1947                0        42.000      0        0
# 1978           25.000             0      0        0
# 1987                0             0      0   50.000
# 1988                0             0 48.000        0
# 1990                0             0      0   30.000
# 1991                0             0      0   35.667
# 1993                0             0      0   56.000
# 1994                0        49.000      0        0
# 1998                0        58.000 31.000        0
# 2000                0        56.000      0        0
# 2001                0             0      0   42.000
# 2003           37.000             0      0        0
# 2004           47.000             0 46.000        0
# 2005                0        55.000      0        0
# 2006                0        52.000      0   45.000
# 2008           29.000        48.667 36.000   57.000
# 2009           58.000             0 29.000        0
# 2010           35.667        50.333 53.500   48.000
# 2011           41.333             0 35.833   50.500
# 2012           36.600        55.000 38.000   51.333
# 2013           34.500        52.364 41.200        0
# 2014           25.000        53.833 35.571   59.000
# 2015           36.750        44.714 30.000   57.667
# 2016           33.571        45.545 36.857   41.000
# 2017           27.000        48.514 49.000   55.000
# 2018           37.800        44.000 34.250   55.929
# 2019           35.174        35.850 30.333   56.714
# 2020           31.667        38.444 32.818   53.167
# 2021           38.400        37.917 35.000   51.000

# %%
# organize data in field country
for _ in range(0, len(netflix_movies)):
    netflix_movies["country"][_] = netflix_movies["country"].values[0:len(netflix_movies)][_].split(", ")[0:]

# %%
# define empty list
countries = []

# insert each element in the country field to countries list 
for i in range (len(netflix_movies)):
    for j in range(len(netflix_movies["country"][i])):
            countries.append(netflix_movies["country"][i][j])

# %%
# finding the top 10 countries that have the most content
country_number = Counter(countries)
sorted(country_number.items(), key = lambda pair: pair[1], reverse = True)
country_number.most_common(10)
# Out:
# [('United States', 2746),
#  ('India', 954),
#  ('United Kingdom', 534),
#  ('Not Specify', 429),
#  ('Canada', 319),
#  ('France', 303),
#  ('Germany', 182),
#  ('Spain', 171),
#  ('Japan', 116),
#  ('China', 114)]

# %%
# demonstrate as grafic
x, y = zip(*country_number.most_common(10))

# set them up as bar
plt.bar(x, y)
plt.title("Country With The Most Content", fontweight = "bold", fontsize = 15)
plt.ylabel("Number Of Content", fontweight = "bold", fontsize = 15)

# rotate country names 90 degrees
plt.xticks(rotation = 90)

# show the plot
plt.show()

# %%
# create a new dataframe to work with movies in usa and turkey
df_TUR = df[(df["country"] == "Turkey") & (df["type"] == "Movie")]
df_USA = df[(df["country"] == "United States") & (df["type"] == "Movie")]

# %%
# selecting specific fields for each dataframe
df_TUR = df_TUR[["title", "director","cast","production","rating","duration"]]
df_USA = df_USA[["title", "director","cast","production","rating","duration"]]

# %%
# finding most popular director in usa and turkey
most_popular_directors_TUR = df_TUR[df_TUR.director != "No Director"]["director"].value_counts().head(10)
most_popular_directors_USA = df_USA[df_USA.director != "No Director"]["director"].value_counts().head(10)

# %%
# finding most popular cast in turkey and usa
most_popular_cast_TUR = df_TUR[df_TUR.cast != "No Cast"]["cast"].value_counts().head(10)
most_popular_cast_USA = df_USA[df_USA.cast != "No Cast"]["cast"].value_counts().head(10)

# %%
# finding top 10 director for turkey
plt.bar(most_popular_directors_TUR.index, most_popular_directors_TUR.values)
plt.title("Most Popular Directors In Turkey", fontweight = "bold", fontsize = 15)
plt.ylabel("Number Of Movie", fontweight = "bold", fontsize = 15)
plt.xticks(rotation = 90)
plt.show()

# %%
# Production names and cast directed by Yılmaz Erdoğan
df_TUR[df_TUR["director"].str.contains("Yılmaz Erdoğan", na = False)][["title", "cast"]]
# Out:
#                                                 title  \
# show_id
# s907     Have You Ever Seen Fireflies? - Theatre Play
# s996                                        Vizontele
# s2606                                    Ekşi Elmalar
# s2621                                    Neseli Hayat
# s2622                                  Organize Isler
# s3403                           Love, Surreal and Odd
# s3890                                      Money Trap
# s5582                           The Butterfly's Dream
# s8683                                 Vizontele Tuuba
#
#                                                       cast
# show_id
# s907     [Demet Akbağ, Zerrin Sümer, Sinan Bengier, Sal...
# s996     [Yılmaz Erdoğan, Demet Akbağ, Altan Erkekli, C...
# s2606    [Yılmaz Erdoğan, Farah Zeynep Abdullah, Songül...
# s2621    [Yılmaz Erdoğan, Ersin Korkut, Büşra Pekin, Er...
# s2622    [Yılmaz Erdoğan, Tolga Çevik, Demet Akbağ, Alt...
# s3403    [Aylin Kontante, Bülent Emrah Parlak, Büşra Pe...
# s3890    [Yılmaz Erdoğan, Kıvanç Tatlıtuğ, Ezgi Mola, B...
# s5582    [Kıvanç Tatlıtuğ, Mert Fırat, Belçim Bilgin, F...
# s8683    [Yılmaz Erdoğan, Tarık Akan, Altan Erkekli, Ce...

# %%
# Production names and cast directed by Hakan Algül
df_TUR[df_TUR["director"].str.contains("Hakan Algül", na = False)][["title", "cast"]]
# Out:
#                        title  \
# show_id
# s979                  Deliha
# s991     Niyazi Gül Dörtnala
# s2025         Night of Knots
# s3428     Bygones Be Bygones
# s6286         Berlin Kaplani
# s6726          Eyyvah Eyyvah
# s6727        Eyyvah Eyyvah 2
# s6728        Eyyvah Eyyvah 3
#
#                                                       cast
# show_id
# s979                [Gupse Özay, Barış Arduç, Cihan Ercan]
# s991     [Ata Demirer, Demet Akbağ, Şebnem Bozoklu, Lev...
# s2025    [Şahin Irmak, İrem Sak, Gonca Vuslateri, Emre ...
# s3428    [Ata Demirer, Tuvana Türkay, Ülkü Duru, Salih ...
# s6286    [Ata Demirer, Necati Bilgiç, Tarık Ünlüoğlu, Ö...
# s6726    [Demet Akbağ, Ata Demirer, Özge Borak, Bican G...
# s6727    [Demet Akbağ, Ata Demirer, Özge Borak, Salih K...
# s6728    [Demet Akbağ, Ata Demirer, Özge Borak, Salih K...

# %% [raw]
# ! The most popular directors to work with in Turkey are "Hakan Algül" and "Yılmaz Erdoğan".
# ! "Hakan Algul" 8 movie; "Yılmaz Erdoğan" directed 7 movies and a theater play, most of which he was involved in as an actor.

# %%
# make a loop where Turkish actors are counted
actor = []
for i in range (len(df_TUR)):
    for j in range(len(df_TUR["cast"][i])):
            actor.append(df_TUR["cast"][i][j])

# %%
# sort counted Turkish actors
cast_number_TUR = Counter(actor)
sorted(cast_number_TUR.items(), key = lambda pair: pair[1], reverse = True)
# Out:
# [('Demet Akbağ', 13),
#  ('Cezmi Baskın', 9),
#  ('Salih Kalyon', 7),
#  ('Ata Demirer', 7),
#  ('Yılmaz Erdoğan', 7),
#  ('Büşra Pekin', 7),
#  ('Devrim Yakut', 6),
#  ('Erdal Tosun', 6),
#  ('Cem Yılmaz', 6),
#  ('Cengiz Bozkurt', 6),
#  ('Tarık Ünlüoğlu', 6),
#  ('Fatih Artman', 5),
#  ('Gupse Özay', 5),
#  ('Eda Ece', 5),
#  ('Tolga Çevik', 5),
#  ('Ersin Korkut', 5),
#  ('Bican Günalan', 4),
#  ('Binnur Kaya', 4),
#  ('Özge Borak', 4),
#  ('Ezgi Mola', 4),
#  ('İbrahim Büyükak', 4),
#  ('Altan Erkekli', 4),
#  ('Gülhan Tekin', 4),
#  ('Belçim Bilgin', 4),
#  ('Zerrin Sümer', 3),
#  ('Engin Günaydın', 3),
#  ('Erdem Yener', 3),
#  ('İrem Sak', 3),
#  ('Cihan Ercan', 3),
#  ('Rasim Öztekin', 3),
#  ('Şinasi Yurtsever', 3),
#  ('Berat Yenilmez', 3),
#  ('Bahar Şahin', 3),
#  ('Gürgen Öz', 3),
#  ('İlker Aksum', 3),
#  ('Bahtiyar Engin', 3),
#  ('Mahir İpek', 3),
#  ('Erkan Can', 3),
#  ('Ahmet Mümtaz Taylan', 3),
#  ('Burcu Gönder', 3),
#  ('Tanju Tuncel', 3),
#  ('Sinan Bengier', 2),
#  ('Onur Buldu', 2),
#  ('Barış Arduç', 2),
#  ('Ahmet Kural', 2),
#  ('Murat Cemcir', 2),
#  ('Barış Yıldız', 2),
#  ('İnan Ulaş Torun', 2),
#  ('Özkan Uğur', 2),
#  ('Ozan Güven', 2),
#  ('Ayda Aksel', 2),
#  ('Somer Karvan', 2),
#  ('Ali Çelik', 2),
#  ('Seda Bakan', 2),
#  ('İştar Gökseven', 2),
#  ('Murat Yıldırım', 2),
#  ('Gülenay Kalkan', 2),
#  ('Oğuzhan Koç', 2),
#  ('Toygan Avanoğlu', 2),
#  ('Şebnem Bozoklu', 2),
#  ('Sebnem Sönmez', 2),
#  ('İclal Aydın', 2),
#  ('Elif Nur Kerkük', 2),
#  ('Suzan Aksoy', 2),
#  ('Esin Eden', 2),
#  ('Mert Turak', 2),
#  ('Sedef Avcı', 2),
#  ('Cemal Hünal', 2),
#  ('Begüm Kütük', 2),
#  ('Engin Altan Düzyatan', 2),
#  ('Sinem Kobal', 2),
#  ('Burcu Kara', 2),
#  ('Haluk Bilginer', 2),
#  ('Öner Erkan', 2),
#  ('Hülya Duyar', 2),
#  ('Emre Karayel', 2),
#  ('Okan Çabalar', 2),
#  ('Nergis Öztürk', 2),
#  ('Hakan Salınmış', 2),
#  ('Şahin Irmak', 2),
#  ('Gonca Vuslateri', 2),
#  ('Zafer Algöz', 2),
#  ('Yosi Mizrahi', 2),
#  ('Mazhar Alanson', 2),
#  ('Buğra Gülsoy', 2),
#  ('Osman Alkaş', 2),
#  ('Çağlar Çorumlu', 2),
#  ('Farah Zeynep Abdullah', 2),
#  ('Özgü Namal', 2),
#  ('Celile Toyon Uysal', 2),
#  ('Hüseyin Avni Danyal', 2),
#  ('Rıza Akın', 2),
#  ('Tuncer Salman', 2),
#  ('Tuna Orhan', 2),
#  ('Ayten Uncuoğlu', 2),
#  ('Serkan Keskin', 2),
#  ('Bülent Emrah Parlak', 2),
#  ('Renan Bilek', 2),
#  ('Seda Güven', 2),
#  ('Toprak Sergen', 2),
#  ('Ali Yoğurtçuoğlu', 2),
#  ('Aksel Bonfil', 2),
#  ('Olgun Toker', 2),
#  ('Murat Boz', 2),
#  ('Kıvanç Tatlıtuğ', 2),
#  ('Ümit Bülent Dinçer', 2),
#  ('Sultan Köroğlu Kılıç', 2),
#  ('Murat Seviş', 2),
#  ('Elçin Atamgüç', 2),
#  ('Nihal Yalçın', 2),
#  ('Meray Ülgen', 2),
#  ('Ayşenil Şamlıoğlu', 2),
#  ('Sermiyan Midyat', 2),
#  ('Bülent Çolak', 2),
#  ('Şebnem Sönmez', 1),
#  ('Serhat Özcan', 1),
#  ('Demet Evgar', 1),
#  ('Erdal Özyağcılar', 1),
#  ('Su Kutlu', 1),
#  ('Gülse Birsel', 1),
#  ('Şevket Çoruh', 1),
#  ('Derya Karadaş', 1),
#  ('Devin Özgür Çınar', 1),
#  ('Alper Kul', 1),
#  ('Onur Atilla', 1),
#  ('Doğa Rutkay', 1),
#  ('Meltem Yılmazkaya', 1),
#  ('İdil Fırat', 1),
#  ('Şafak Sezer', 1),
#  ('Özge Özberk', 1),
#  ('Ali Sunal', 1),
#  ('Hatice Şendil', 1),
#  ('Ahmet Saraçoğlu', 1),
#  ('Janset', 1),
#  ('Erkan Kolçak Köstendil', 1),
#  ('Ebru Cündübeyoğlu', 1),
#  ('Begüm Öner', 1),
#  ('Gül Arıcı', 1),
#  ('Muhammet Uzuner', 1),
#  ('Nevra Serezli', 1),
#  ('Emre Kınay', 1),
#  ('Aslı Bekiroğlu', 1),
#  ('Muharrem Bayrak', 1),
#  ('Levent Ülgen', 1),
#  ('Mesut Çakarli', 1),
#  ('Zeynep Tokuş', 1),
#  ('Meryem Uzerli', 1),
#  ('Feyyaz Duman', 1),
#  ('Hakan Karsak', 1),
#  ('Şennur Nogaylar', 1),
#  ('Burcu Salihoğlu', 1),
#  ('Ayhan Taş', 1),
#  ('Emin Olcay', 1),
#  ('Muharrem Gülmez', 1),
#  ('Tarık Papuççuoğlu', 1),
#  ('Doğa Konakoğlu', 1),
#  ('Deniz Özerman', 1),
#  ('Talat Bulut', 1),
#  ('Mahsun Kırmızıgül', 1),
#  ('Erol Demiröz', 1),
#  ('Ali Sürmeli', 1),
#  ('Meral Çetinkaya', 1),
#  ('Çağatay Ulusoy', 1),
#  ('Emir Ali Doğrul', 1),
#  ('Ersin Arıcı', 1),
#  ('Turgay Tanülkü', 1),
#  ('Selen Öztürk', 1),
#  ('Osman İskender Bayer', 1),
#  ('Tomris Çetinel', 1),
#  ('Volkan Çalışkan', 1),
#  ('Mehmet Bahattin Genç', 1),
#  ('Okşan Büyük', 1),
#  ('Kubilay Penbeklioğlu', 1),
#  ('Öykü Çelik', 1),
#  ('Gökçe Özyol', 1),
#  ('Melis Birkan', 1),
#  ('Tuna Çevik', 1),
#  ('Gülçin Santırcıoğlu', 1),
#  ('Göktuğ Yıldırım', 1),
#  ('Helin Kandemir', 1),
#  ('Elçin Sangu', 1),
#  ('Fırat Tanış', 1),
#  ('Alican Yücesoy', 1),
#  ('Emre Kıvılcım', 1),
#  ('Hakan Eke', 1),
#  ('İhsan Ceylan', 1),
#  ('Bimen Zartar', 1),
#  ('Mert Yazıcıoğlu', 1),
#  ('Afra Saraçoğlu', 1),
#  ('Yiğit Kirazcı', 1),
#  ('Orkun Işıtmak', 1),
#  ('Tolga Canbeyli', 1),
#  ('Bada Oh Deniz', 1),
#  ('Hakan Kurtaş', 1),
#  ('Doğaç Yildiz', 1),
#  ('Ceren Moray', 1),
#  ('Ececan Gümeci', 1),
#  ('Ümit Erdim', 1),
#  ('Cem Kiliç', 1),
#  ('Haldun Boysan', 1),
#  ('Ferdi Akarnur', 1),
#  ('Mine Teber', 1),
#  ('Güneş Hayat', 1),
#  ('Demet Özdemir', 1),
#  ('Uraz Kaygılaroğlu', 1),
#  ('Bora Cengiz', 1),
#  ('Meltem Gülenç', 1),
#  ('Duygu Yetiş', 1),
#  ('Bilge Şen', 1),
#  ('Nilgün Belgün', 1),
#  ('Hakan Akın', 1),
#  ('Nur Aysan', 1),
#  ('Ruhi Sarı', 1),
#  ('Nadir Sarıbacak', 1),
#  ('Serkan Ercan', 1),
#  ('Sermet Yeşil', 1),
#  ('Enes Mazak', 1),
#  ('Zafer Diper', 1),
#  ('Irina Ivkina', 1),
#  ('Çetin Altay', 1),
#  ('Can Yılmaz', 1),
#  ('Fevzi Gökçe', 1),
#  ('Tülin Özen', 1),
#  ('Cahit Gök', 1),
#  ('Metin Coşkun', 1),
#  ('Tuğrul Tülek', 1),
#  ('Dilan Çiçek Deniz', 1),
#  ('Metin Akdülger', 1),
#  ('Özge Özpirinçci', 1),
#  ('Yusuf Akgün', 1),
#  ('Füsun Demirel', 1),
#  ('Gözde Türkpençe', 1),
#  ('Rahmi Dilligil', 1),
#  ('Uğur Bilgin', 1),
#  ('Öner Ateş', 1),
#  ('Hakan Ummak', 1),
#  ('Patrycja Widlak', 1),
#  ('Hamza Yazıcı', 1),
#  ('Songül Öden', 1),
#  ('Şükran Ovalı', 1),
#  ('Şükrü Özyıldız', 1),
#  ('Caner Cindoruk', 1),
#  ('Umut Kurt', 1),
#  ('Nazmi Kırık', 1),
#  ('Bahri Beyat', 1),
#  ('Meral Okay', 1),
#  ('Dilber Ay', 1),
#  ('Oktay Kaynarca', 1),
#  ('Burak Tamdoğan', 1),
#  ('Nurgül Yeşilçay', 1),
#  ('Deniz Deha Lostar', 1),
#  ('Settar Tanrıöğen', 1),
#  ('Jülide Kural', 1),
#  ('Ragıp Savaş', 1),
#  ('Dilşah Demir', 1),
#  ('Zeynep Koçak', 1),
#  ('Ayberk Atilla', 1),
#  ('Fatma Murat', 1),
#  ('Metin Yıldız', 1),
#  ('Ebru Akel', 1),
#  ('Başak Köklükaya', 1),
#  ('Müfit Can Saçıntı', 1),
#  ('Ünal Yeter', 1),
#  ('Uğur Demirpehlivan', 1),
#  ('Ayşen Gruda', 1),
#  ('Banu Manioğlu', 1),
#  ('Aslı İnandık', 1),
#  ('Caner Özyurtlu', 1),
#  ('Melis İşiten', 1),
#  ('Aslı Turanlı', 1),
#  ('Ahmet Olgun Sünear', 1),
#  ('Seda Türkmen', 1),
#  ('Aras Bulut İynemli', 1),
#  ('Nisa Sofiya Aksongur', 1),
#  ('Deniz Baysal', 1),
#  ('Mesut Akusta', 1),
#  ('Nehir Erdoğan', 1),
#  ('Tardu Flordun', 1),
#  ('İlker Kaleli', 1),
#  ('Esra Bezen Bilgin', 1),
#  ('Aytaç Uşun', 1),
#  ('Cem Özeren', 1),
#  ('Caner Arçkan', 1),
#  ('Aylin Kontante', 1),
#  ('Tuvana Türkay', 1),
#  ('Ülkü Duru', 1),
#  ('Bedir Bedir', 1),
#  ('Gümeç Alpay Aslan', 1),
#  ('Cem Gelinoğlu', 1),
#  ('Melis Babadag', 1),
#  ('Ege Kökenli', 1),
#  ('Müfit Kayacan', 1),
#  ('Lale Başar', 1),
#  ('Ali Erkazan', 1),
#  ('Özlem Çakar', 1),
#  ('Selen Domaç', 1),
#  ('Ferdi Sancar', 1),
#  ('Güven Hokna', 1),
#  ('Selim Bayraktar', 1),
#  ('Berat Efe Parlar', 1),
#  ('Esat Polat Güler', 1),
#  ('Eda Döğer', 1),
#  ('Dora Dalgıç', 1),
#  ('Taha Sönmezisik', 1),
#  ('Zeynep Ilgin Çelik', 1),
#  ('Arda Taşarcan', 1),
#  ('Alperen Efe Esmer', 1),
#  ('İlknur Külahlıoglu', 1),
#  ('İkra Külahlıoğlu', 1),
#  ('Derya Alabora', 1),
#  ('Mert Öner', 1),
#  ('Ezgi Eyüboğlu', 1),
#  ('Kadir Polatçi', 1),
#  ('Aycan Koptur', 1),
#  ('Kıvanç Baran Arslan', 1),
#  ('Hande Dane', 1),
#  ('Açelya Topaloğlu', 1),
#  ('Özgür Emre Yıldırım', 1),
#  ('Dilşad Şimşek', 1),
#  ('Bensu Soral', 1),
#  ('Rıza Kocaoğlu', 1),
#  ('Güven Kıraç', 1),
#  ('Nil Günal', 1),
#  ('Emir Özbek Yıldız', 1),
#  ('Pelin Acar', 1),
#  ('Cansu Kurgun', 1),
#  ('Irmak Örnek', 1),
#  ('A. Murat Özgen', 1),
#  ('Sabriye Günüç', 1),
#  ('Furkan Bayraktar', 1),
#  ('Mehmet Canbeg', 1),
#  ('Oguzhan Kocakli', 1),
#  ('Mert Fırat', 1),
#  ('Taner Birsel', 1),
#  ('Selman Ünlüsoy', 1),
#  ('İpek Bilgin', 1),
#  ('Ayça Erturan', 1),
#  ('Aydan Taş', 1),
#  ('Ayşegül Akdemir', 1),
#  ('Emre Canpolat', 1),
#  ('Eser Yenenler', 1),
#  ('Gizem Tuğral', 1),
#  ('Gülsüm Alkan', 1),
#  ('Hamdi Kahraman', 1),
#  ('Metin Keçeci', 1),
#  ('Mehmet Günsür', 1),
#  ('Berna Konur', 1),
#  ('Çetin Tekindor', 1),
#  ('Fikret Kuşkan', 1),
#  ('Hümeyra', 1),
#  ('Ege Tanman', 1),
#  ('Şerif Sezer', 1),
#  ('Yetkin Dikinciler', 1),
#  ('Mahmut Gökgöz', 1),
#  ('Nergis Çorakçi', 1),
#  ('Bilge Sen', 1),
#  ('Hande Doğandemir', 1),
#  ('Ercan Yazgan', 1),
#  ('Sadi Celil Cengiz', 1),
#  ('Burcu Biricik', 1),
#  ('Gürkan Uygun', 1),
#  ('Gökçe Bahadır', 1),
#  ('Necati Bilgiç', 1),
#  ('Özlem Türkad', 1),
#  ('Cemil Özbayer', 1),
#  ('Orhan Güner', 1),
#  ('Mert Aran', 1),
#  ('Sema Şimşek', 1),
#  ('Nilay Gök', 1),
#  ('Volkan Ünal', 1),
#  ('Fehmi Karaarslan', 1),
#  ('Ömer Duran', 1),
#  ('Aybike Turan', 1),
#  ('Burak Çimen', 1),
#  ('Serra Yılmaz', 1),
#  ('Ayberk Attila', 1),
#  ('Mine Şenhuy Teber', 1),
#  ('Doğukan Polat', 1),
#  ('İdil Dizdar', 1),
#  ('Hülya Gülsen Irmak', 1),
#  ('Canan Özer', 1),
#  ('Şenay Bozoklar', 1),
#  ('Emrah Kaman', 1),
#  ('Müjde Uzman', 1),
#  ('Özlem Tekin', 1),
#  ('Kemal İnci', 1),
#  ('Caner Alkaya', 1),
#  ('Ayçe Abana', 1),
#  ('Halil Sezai Paracıkoğlu', 1),
#  ('Şafak Pekdemir', 1),
#  ('Ahmet Uz', 1),
#  ('Mehmet Selim Akgül', 1),
#  ('Sinan Çalışkanoğlu', 1),
#  ('Tuğba Sarıünal', 1),
#  ('Asuman Dabak', 1),
#  ('Ayten Soykök', 1),
#  ('Damla Sönmez', 1),
#  ('Mete Horozoğlu', 1),
#  ('Yavuz Bingöl', 1),
#  ('Hüseyin Soysalan', 1),
#  ('Tolga Karaçelik', 1),
#  ('Murat Başoğlu', 1),
#  ('Mustafa Uzunyılmaz', 1),
#  ('Nusret Çetinel', 1),
#  ('Ayşenur Yazıcı', 1),
#  ('İbrahim Çelikkol', 1),
#  ('Kerem Can', 1),
#  ('Necmi Yapıcı', 1),
#  ('Levent Sülün', 1),
#  ('Erol Gedik', 1),
#  ('Köksal Engür', 1),
#  ('Pelin Körmükçü', 1),
#  ('Zeynep Özder', 1),
#  ('Tarık Akan', 1),
#  ('Tuba Ünsal', 1)]

# %%
# most popular 10 Turkish actors who acted in the most production
cast_number_TUR.most_common(10)
# Out:
# [('Demet Akbağ', 13),
#  ('Cezmi Baskın', 9),
#  ('Salih Kalyon', 7),
#  ('Ata Demirer', 7),
#  ('Yılmaz Erdoğan', 7),
#  ('Büşra Pekin', 7),
#  ('Devrim Yakut', 6),
#  ('Erdal Tosun', 6),
#  ('Cem Yılmaz', 6),
#  ('Cengiz Bozkurt', 6)]

# %%
# Plot the most popular 10 Turkish actors who acted in the most production as a bar chart 
x, y = zip(*cast_number_TUR.most_common(10))
plt.bar(x, y)
plt.title("Most Popular Cast In Turkey", fontweight = "bold", fontsize = 15)
plt.ylabel("Number Of Movie", fontweight = "bold", fontsize = 15)
plt.xticks(rotation = 90)
plt.show()

# %% [raw]
# ! "Demet Akbağ", who acted 13 films in total, worked with 2 different directors who directed the most productions in Turkey
# ! in 7 films (one theater play), proved to be the most popular actress by far.
# ! Then, respectively, "Cezmi Baskin" and "Salih Kalyon" come.

# %% [raw]
# ! Actors who work closely and are compatible with each other in Turkey are usually actors who have acted together
# ! in more than one movie. For example, the most cooperative players in Turkey are "Demet Akbağ" and "Ata Demirer".
# ! They have acted in 4 movies together. Ozge Borak and Salih Kalyon, with whom they played together in the same film series
# ! (Eyyvah Eyyvah), can be included. As can be seen, although the same actors come together due to the nature of the serial films,
# ! it is noteworthy that most of these films are in the "comedy" genre.

# %% [raw]
# ! The closest working actor/director pairs in Turkey are typically those with a strong working relationship.
# ! For example, the most collaborating actor/director trio in Turkey is "Demet Akbağ", "Ata Demirer" and "Hakan Algül".
# ! "They worked together in 4 projects in total.

# %%
# finding top 10 director for united states
plt.bar(most_popular_directors_USA.index, most_popular_directors_USA.values)
plt.title("Most Popular Director In United States", fontweight = "bold", fontsize = 15)
plt.ylabel("Number Of Movie", fontweight = "bold", fontsize = 15)
plt.xticks(rotation = 90)
plt.show()

# %% [raw]
# ! The most popular directors to work with in the USA are "Martin Scorsese", "Robert Rodriguez" and "Steven Spielberg".
# ! "Martin Scorsese" directed 8 movies, "Steven Spielberg" and Robert Rodriguez" directed 6 movies.

# %%
# Production names and cast directed by Jay Karas
df_USA[df_USA["director"].str.contains("Jay Karas", na = False)][["title", "cast"]] #stand up
# Out:
#                                                      title  \
# show_id
# s2696                                       The Main Event
# s3647                      Demetri Martin: The Overthinker
# s3734                  Adam Devine: Best Time of Our Lives
# s4804               Bill Burr: You People Are All the Same
# s4864                            Ali Wong: Hard Knock Wife
# s5087                              Tom Segura: Disgraceful
# s5231                         Christina P: Mother Inferior
# s5623                         Bill Burr: Walk Your Way Out
# s5809    Jeff Foxworthy and Larry the Cable Guy: We’ve ...
# s5818                           Jim Gaffigan: Mr. Universe
# s5848                                 Ali Wong: Baby Cobra
# s5876                           Tom Segura: Mostly Stories
# s5895                           Anjelah Johnson: Not Fancy
# s5900                   Demetri Martin: Live (At the Time)
# s5922               Bill Burr: I'm Sorry You Feel That Way
#
#                                                       cast
# show_id
# s2696    [Seth Carr, Tichina Arnold, Adam Pally, Ken Ma...
# s3647                                     [Demetri Martin]
# s3734                                        [Adam Devine]
# s4804                                          [Bill Burr]
# s4864                                           [Ali Wong]
# s5087                                         [Tom Segura]
# s5231                                [Christina Pazsitzky]
# s5623                                          [Bill Burr]
# s5809                [Jeff Foxworthy, Larry the Cable Guy]
# s5818                                       [Jim Gaffigan]
# s5848                                           [Ali Wong]
# s5876                                         [Tom Segura]
# s5895                              [Anjelah Johnson-Reyes]
# s5900                                     [Demetri Martin]
# s5922                                          [Bill Burr]

# %%
# Production names and cast directed by Marcus Raboy
df_USA[df_USA["director"].str.contains("Marcus Raboy", na = False)][["title", "cast"]] #stand up
# Out:
#                                                      title  \
# show_id
# s2850                Taylor Tomlinson: Quarter-Life Crisis
# s3777                      Miranda Sings Live…Your Welcome
# s3878         Anthony Jeselnik: Fire in the Maternity Ward
# s4315                                   Vir Das: Losing It
# s4789                         Katt Williams: Kattpacalypse
# s4852    Steve Martin and Martin Short: An Evening You ...
# s5025                              Marlon Wayans: Woke-ish
# s5128                              Judd Apatow: The Return
# s5172                        DeRay Davis: How to Act Black
# s5316                            Ryan Hamilton: Happy Face
# s5320                        Lynne Koplitz: Hormonal Beast
# s5519                        Vir Das: Abroad Understanding
# s5628                        Cristela Alonzo: Lower Classy
# s5725                 Dana Carvey: Straight White Male, 60
#
#                                  cast
# show_id
# s2850              [Taylor Tomlinson]
# s3777             [Colleen Ballinger]
# s3878              [Anthony Jeselnik]
# s4315                       [Vir Das]
# s4789                 [Katt Williams]
# s4852    [Steve Martin, Martin Short]
# s5025                 [Marlon Wayans]
# s5128                   [Judd Apatow]
# s5172                   [DeRay Davis]
# s5316                 [Ryan Hamilton]
# s5320                 [Lynne Koplitz]
# s5519                       [Vir Das]
# s5628               [Cristela Alonzo]
# s5725                   [Dana Carvey]

# %%
# Production names and cast directed by Jay Chapman
df_USA[df_USA["director"].str.contains("Jay Chapman", na = False)][["title", "cast"]] #stand up
# Out:
#                                  title  \
# show_id
# s3646         D.L. Hughley: Contrarian
# s4223    Moshe Kasher: Live in Oakland
# s4249     Todd Glass: Stand-Up Special
# s5109          Todd Barry: Spicy Honey
# s5135     Craig Ferguson: Tickle Fight
# s5326      Brad Paisley's Comedy Rodeo
# s5327    Colin Quinn: Unconstitutional
# s5379              D.L. Hughley: Clear
# s5380    Tom Segura: Completely Normal
# s5526         Lucas Brothers: On Drugs
# s5819           Jim Gaffigan: Obsessed
# s7057      Iliza Shlesinger: War Paint
#
#                                                       cast
# show_id
# s3646                                       [D.L. Hughley]
# s4223                                       [Moshe Kasher]
# s4249                                         [Todd Glass]
# s5109                                         [Todd Barry]
# s5135                                     [Craig Ferguson]
# s5326    [Brad Paisley, Nate Bargatze, John Heffron, Jo...
# s5327                                        [Colin Quinn]
# s5379                                       [D.L. Hughley]
# s5380                                         [Tom Segura]
# s5526                           [Keith Lucas, Kenny Lucas]
# s5819                                       [Jim Gaffigan]
# s7057                                   [Iliza Shlesinger]

# %%
# Production names and cast directed by Shannon Hartman
df_USA[df_USA["director"].str.contains("Shannon Hartman", na = False)][["title", "cast"]] # stand-up
# Out:
#                                        title             cast
# show_id
# s2979     Kevin Hart: I'm a Grown Little Man     [Kevin Hart]
# s3621                   Jim Jefferies : BARE  [Jim Jefferies]
# s3759                  Jo Koy: Comin' In Hot         [Jo Koy]
# s4815    W. Kamau Bell: Private School Negro  [W. Kamau Bell]
# s5558              Jo Koy: Live from Seattle         [Jo Koy]
# s5577          Jim Norton: Mouthful of Shame     [Jim Norton]
# s5713                  Donald Glover: Weirdo  [Donald Glover]
# s6311                   Bill Burr: Let It Go      [Bill Burr]
# s7181            Kevin Hart: Seriously Funny     [Kevin Hart]

# %%
# Production names and cast directed by Troy Miller
df_USA[df_USA["director"].str.contains("Troy Miller", na = False)][["title", "cast"]] #stand up
# Out:
#                                                 title  \
# show_id
# s1190    Nate Bargatze: The Greatest Average American
# s1279                       Brian Regan: On the Rocks
# s2322              George Lopez: We'll Do It For Half
# s3496                     Jeff Dunham: Beside Himself
# s5162        Brian Regan: Nunchucks and Flamethrowers
# s5794     Cedric the Entertainer: Live from the Ville
# s5817                         Jim Gaffigan: King Baby
# s6656         Dumb and Dumberer: When Harry Met Lloyd
#
#                                                       cast
# show_id
# s1190                                      [Nate Bargatze]
# s1279                                        [Brian Regan]
# s2322                                       [George Lopez]
# s3496                                        [Jeff Dunham]
# s5162                                        [Brian Regan]
# s5794                             [Cedric the Entertainer]
# s5817                                       [Jim Gaffigan]
# s6656    [Eric Christian Olsen, Derek Richardson, Rache...

# %%
# Production names and cast directed by Martin Scorsese
df_USA[df_USA["director"].str.contains("Martin Scorsese", na = False)][["title", "cast"]]
# Out:
#                                                      title  \
# show_id
# s1359                                       Shutter Island
# s3228                                         The Irishman
# s3760    Rolling Thunder Revue: A Bob Dylan Story by Ma...
# s6112                      Alice Doesn't Live Here Anymore
# s6881                                           GoodFellas
# s7432                                         Mean Streets
# s7821                                          Raging Bull
# s8736                      Who's That Knocking at My Door?
#
#                                                       cast
# show_id
# s1359    [Leonardo DiCaprio, Mark Ruffalo, Ben Kingsley...
# s3228    [Robert De Niro, Al Pacino, Joe Pesci, Harvey ...
# s3760    [Bob Dylan, Allen Ginsberg, Joan Baez, Patti S...
# s6112    [Ellen Burstyn, Kris Kristofferson, Billy Gree...
# s6881    [Robert De Niro, Ray Liotta, Joe Pesci, Lorrai...
# s7432    [Robert De Niro, Harvey Keitel, David Proval, ...
# s7821    [Robert De Niro, Cathy Moriarty, Joe Pesci, Fr...
# s8736    [Zina Bethune, Harvey Keitel, Anne Collette, L...

# %%
# Production names and cast directed by Ryan Polito
df_USA[df_USA["director"].str.contains("Ryan Polito", na = False)][["title", "cast"]] #stand up
# Out:
#                                      title  \
# show_id
# s3442              Deon Cole: Cole Hearted
# s3975     Nate Bargatze: The Tennessee Kid
# s4084          Bert Kreischer: The Machine
# s4939    Seth Rogen's Hilarity for Charity
# s4951            John Mulaney: New in Town
# s5481          Tracy Morgan: Staying Alive
# s5836              Jim Jefferies: Freedumb
#
#                                                       cast
# show_id
# s3442                                          [Deon Cole]
# s3975                                      [Nate Bargatze]
# s4084                                     [Bert Kreischer]
# s4939    [Seth Rogen, Ike Barinholtz, Michael Che, Sach...
# s4951                                       [John Mulaney]
# s5481                                       [Tracy Morgan]
# s5836                                      [Jim Jefferies]

# %%
# Production names and cast directed by Lance Bangs
df_USA[df_USA["director"].str.contains("Lance Bangs", na = False)][["title", "cast"]] # stand up
# Out:
#                                                      title               cast
# show_id
# s3161                             Michelle Wolf: Joke Show    [Michelle Wolf]
# s3620                                      I'm Brent Morin      [Brent Morin]
# s4451                              Marc Maron: Thinky Pain       [Marc Maron]
# s5647                       Jen Kirkman: Just Keep Livin’?      [Jen Kirkman]
# s5869                     Hannibal Buress: Comedy Camisado  [Hannibal Buress]
# s5912    Jen Kirkman: I'm Gonna Die Alone (And I Feel F...      [Jen Kirkman]
# s5925                   Chelsea Peretti: One of the Greats  [Chelsea Peretti]

# %%
# Production names and cast directed by Leslie Small
df_USA[df_USA["director"].str.contains("Leslie Small", na = False)][["title", "cast"]] # stand up
# Out:
#                                 title  \
# show_id
# s1687    Kevin Hart: Zero F**ks Given
# s3219                    Holiday Rush
# s3310            Undercover Brother 2
# s3953       Kevin Hart: Irresponsible
# s5536           Kevin Hart: What Now?
# s7179    Kevin Hart: Laugh at My Pain
# s7180      Kevin Hart: Let Me Explain
#
#                                                       cast
# show_id
# s1687                                         [Kevin Hart]
# s3219    [Romany Malco, Sonequa Martin-Green, Darlene L...
# s3310    [Michael Jai White, Vince Swann, Barry Bostwic...
# s3953                                         [Kevin Hart]
# s5536    [Kevin Hart, Don Cheadle, Halle Berry, Ed Helm...
# s7179                                         [Kevin Hart]
# s7180                                         [Kevin Hart]

# %%
# Production names and cast directed by Robert Rodriguez 
df_USA[df_USA["director"].str.contains("Robert Rodriguez", na = False)][["title", "cast"]]
# Out:
#                                            title  \
# show_id
# s864         Spy Kids: All the Time in the World
# s1495                           We Can Be Heroes
# s8075                                   Spy Kids
# s8076      Spy Kids 2: The Island of Lost Dreams
# s8077                      Spy Kids 3: Game Over
# s8184    The Adventures of Sharkboy and Lavagirl
#
#                                                       cast
# show_id
# s864     [Jessica Alba, Joel McHale, Rowan Blanchard, M...
# s1495    [YaYa Gosselin, Pedro Pascal, Priyanka Chopra,...
# s8075    [Antonio Banderas, Carla Gugino, Alan Cumming,...
# s8076    [Antonio Banderas, Carla Gugino, Alexa PenaVeg...
# s8077    [Daryl Sabara, Sylvester Stallone, Ricardo Mon...
# s8184    [Taylor Lautner, Taylor Dooley, Cayden Boyd, G...

# %%
# Production names and cast directed by Steven Spielberg 
df_USA[df_USA["director"].str.contains("Steven Spielberg", na = False)][["title", "cast"]]
# Out:
#                                                      title  \
# show_id
# s42                                                   Jaws
# s7071    Indiana Jones and the Kingdom of the Crystal S...
# s7072                   Indiana Jones and the Last Crusade
# s7073        Indiana Jones and the Raiders of the Lost Ark
# s7074                 Indiana Jones and the Temple of Doom
# s7958                                     Schindler's List
#
#                                                       cast
# show_id
# s42      [Roy Scheider, Robert Shaw, Richard Dreyfuss, ...
# s7071    [Harrison Ford, Cate Blanchett, Karen Allen, R...
# s7072    [Harrison Ford, Sean Connery, Denholm Elliott,...
# s7073    [Harrison Ford, Karen Allen, Paul Freeman, Ron...
# s7074    [Harrison Ford, Kate Capshaw, Amrish Puri, Ros...
# s7958    [Liam Neeson, Ben Kingsley, Ralph Fiennes, Car...

# %%
# Production names and cast directed by Sylvester Stallone
df_USA[df_USA["director"].str.contains("Sylvester Stallone", na = False)][["title", "cast"]] # film serisi
# Out:
#              title                                               cast
# show_id
# s7881     Rocky II  [Sylvester Stallone, Talia Shire, Burt Young, ...
# s7882    Rocky III  [Sylvester Stallone, Talia Shire, Burt Young, ...
# s7883     Rocky IV  [Sylvester Stallone, Talia Shire, Burt Young, ...

# %%
df_USA[df_USA["title"].str.contains("Matrix", na = False)][["director", "cast"]] # film serisi
# Out:
#                                 director  \
# show_id
# s8415    Lilly Wachowski, Lana Wachowski
# s8416    Lilly Wachowski, Lana Wachowski
# s8417    Lilly Wachowski, Lana Wachowski
#
#                                                       cast
# show_id
# s8415    [Keanu Reeves, Laurence Fishburne, Carrie-Anne...
# s8416    [Keanu Reeves, Laurence Fishburne, Carrie-Anne...
# s8417    [Keanu Reeves, Laurence Fishburne, Carrie-Anne...

# %%
df_USA = df_USA[df_USA["cast"] != "No Cast"]

# %%
df_USA["cast"]
# Out:
# show_id
# s10      [Melissa McCarthy, Chris O'Dowd, Kevin Kline, ...
# s28      [Adam Sandler, Kevin James, Chris Rock, David ...
# s29      [Keri Russell, Josh Hamilton, J.K. Simmons, Da...
# s42      [Roy Scheider, Robert Shaw, Richard Dreyfuss, ...
# s43      [Roy Scheider, Lorraine Gary, Murray Hamilton,...
#                                ...
# s8792    [Charlize Theron, Patton Oswalt, Patrick Wilso...
# s8794    [Dennis Quaid, Rene Russo, Sean Faris, Katija ...
# s8803    [Mark Ruffalo, Jake Gyllenhaal, Robert Downey ...
# s8805    [Jesse Eisenberg, Woody Harrelson, Emma Stone,...
# s8806    [Tim Allen, Courteney Cox, Chevy Chase, Kate M...
# Name: cast, Length: 1859, dtype: object

# %%
# make a loop where American actors are counted
actor2 = []
for i in range (len(df_USA)):
    for j in range(len(df_USA["cast"][i])):
            actor2.append(df_USA["cast"][i][j])

# %%
# sort counted American actors
cast_number_USA = Counter(actor2)
sorted(cast_number_USA.items(), key = lambda pair: pair[1], reverse = True)
# Out:
# [('Adam Sandler', 20),
#  ('Samuel L. Jackson', 17),
#  ('Laura Bailey', 14),
#  ('Molly Shannon', 13),
#  ('James Franco', 13),
#  ('Nicolas Cage', 13),
#  ('Chris Rock', 12),
#  ('Dennis Quaid', 12),
#  ('Seth Rogen', 12),
#  ('Fred Tatasciore', 12),
#  ('Erin Fitzgerald', 12),
#  ('Kate Higgins', 12),
#  ('Woody Harrelson', 11),
#  ('Martin Lawrence', 11),
#  ('Mike Epps', 11),
#  ('Michael Peña', 11),
#  ('Kristen Stewart', 11),
#  ('Amy Adams', 11),
#  ('Ray Liotta', 11),
#  ('Kevin Hart', 11),
#  ('Morgan Freeman', 11),
#  ('Danny Trejo', 11),
#  ('Kevin James', 10),
#  ('David Koechner', 10),
#  ('Bruce Willis', 10),
#  ('John C. Reilly', 10),
#  ('Danny McBride', 10),
#  ('Will Ferrell', 10),
#  ('Will Smith', 10),
#  ('John Travolta', 10),
#  ('Steve Buscemi', 10),
#  ('Zach Galifianakis', 10),
#  ('Liev Schreiber', 10),
#  ('Nick Swardson', 10),
#  ('Loretta Devine', 9),
#  ('David Spade', 9),
#  ('Rob Schneider', 9),
#  ('Maria Bello', 9),
#  ('Maya Rudolph', 9),
#  ('Ryan Reynolds', 9),
#  ('Laurence Fishburne', 9),
#  ('Cedric the Entertainer', 9),
#  ('Taylor Lautner', 9),
#  ('Julia Roberts', 9),
#  ('Peter Facinelli', 9),
#  ('Cam Gigandet', 9),
#  ('Don Cheadle', 9),
#  ('Robert De Niro', 9),
#  ('Michael Jai White', 9),
#  ('Terrence Howard', 9),
#  ('Keanu Reeves', 9),
#  ('Bobby Cannavale', 9),
#  ('Gerard Butler', 9),
#  ('Jeff Dunham', 9),
#  ('Debi Derryberry', 9),
#  ('Salma Hayek', 8),
#  ('Denzel Washington', 8),
#  ('Glenn Close', 8),
#  ('Ben Stiller', 8),
#  ('Eddie Murphy', 8),
#  ('John Malkovich', 8),
#  ('Rosario Dawson', 8),
#  ('Ashley Greene', 8),
#  ('Julianne Moore', 8),
#  ('Anthony Mackie', 8),
#  ('Luis Guzmán', 8),
#  ('Halle Berry', 8),
#  ('John Leguizamo', 8),
#  ('Kathy Bates', 8),
#  ('Jennifer Garner', 8),
#  ('Frank Grillo', 8),
#  ('Robert Pattinson', 8),
#  ('Anna Kendrick', 8),
#  ('Rob Riggle', 8),
#  ('Bill Murray', 8),
#  ('Mindy Sterling', 8),
#  ('T.J. Miller', 8),
#  ('Jane Lynch', 8),
#  ('Alfre Woodard', 8),
#  ('Anthony Anderson', 8),
#  ('Willem Dafoe', 8),
#  ('Ken Jeong', 8),
#  ('Dermot Mulroney', 8),
#  ('Alec Baldwin', 8),
#  ('John Michael Higgins', 8),
#  ('Justin Long', 8),
#  ('America Young', 8),
#  ('Luke Wilson', 8),
#  ('Kathryn Hahn', 8),
#  ('Steve Zahn', 8),
#  ('Adam Scott', 8),
#  ('Michael Shannon', 8),
#  ('Keegan-Michael Key', 8),
#  ('Terry Crews', 8),
#  ('Fred Armisen', 8),
#  ('Jeff Garlin', 8),
#  ('Patrick Warburton', 8),
#  ('Harvey Keitel', 8),
#  ('Joan Cusack', 8),
#  ('Ron Perlman', 8),
#  ('Carla Gugino', 8),
#  ('Cindy Robinson', 8),
#  ('Cam Clarke', 8),
#  ('Salli Saffioti', 8),
#  ('Snoop Dogg', 7),
#  ('Harrison Ford', 7),
#  ('Richard Jenkins', 7),
#  ('Bernie Mac', 7),
#  ('Stanley Tucci', 7),
#  ('Sarah Jessica Parker', 7),
#  ('Andy Richter', 7),
#  ('William H. Macy', 7),
#  ('Janeane Garofalo', 7),
#  ('Mike Vogel', 7),
#  ('Jada Pinkett Smith', 7),
#  ('David Oyelowo', 7),
#  ('Elizabeth Banks', 7),
#  ('Kevin Corrigan', 7),
#  ('Naomi Watts', 7),
#  ('Jackson Rathbone', 7),
#  ('Dakota Fanning', 7),
#  ('Laura Linney', 7),
#  ('Joe Pantoliano', 7),
#  ('Jon Lovitz', 7),
#  ('Lacey Chabert', 7),
#  ('Toby Huss', 7),
#  ('Leslie Bibb', 7),
#  ('Judy Greer', 7),
#  ('Will Forte', 7),
#  ('Sam Shepard', 7),
#  ('Keith David', 7),
#  ('Shea Whigham', 7),
#  ('Forest Whitaker', 7),
#  ('Gary Oldman', 7),
#  ('Noah Centineo', 7),
#  ('Jonah Hill', 7),
#  ('Tiffany Haddish', 7),
#  ('Jim Cummings', 7),
#  ('Tara Strong', 7),
#  ('Ben Kingsley', 7),
#  ('Tony Todd', 7),
#  ('Kat Graham', 7),
#  ('George Clooney', 7),
#  ('Viola Davis', 7),
#  ('Oprah Winfrey', 7),
#  ('Jake Gyllenhaal', 7),
#  ('Common', 7),
#  ('Sean Astin', 7),
#  ('Andrew Bachelor', 7),
#  ('John Goodman', 7),
#  ('Jim Gaffigan', 7),
#  ('Alia Shawkat', 7),
#  ('John Mulaney', 7),
#  ('Al Pacino', 7),
#  ('Bruce Dern', 7),
#  ('Robert Patrick', 7),
#  ('Mark Duplass', 7),
#  ('Lucy Liu', 7),
#  ('Tracy Morgan', 7),
#  ('Melanie Lynskey', 7),
#  ('Elise Neal', 7),
#  ('Audu Paden', 7),
#  ('Colin Quinn', 6),
#  ('J.K. Simmons', 6),
#  ('Ethan Hawke', 6),
#  ('Jay O. Sanders', 6),
#  ('Pierce Brosnan', 6),
#  ('Michael Madsen', 6),
#  ('Gary Cole', 6),
#  ('Alfred Molina', 6),
#  ('James Marsden', 6),
#  ('Gillian Jacobs', 6),
#  ('Ethan Suplee', 6),
#  ('Bill Burr', 6),
#  ('Charles Grodin', 6),
#  ('Oliver Platt', 6),
#  ('Philip Baker Hall', 6),
#  ('Amber Heard', 6),
#  ('Chris Cooper', 6),
#  ('Topher Grace', 6),
#  ('James Remar', 6),
#  ('Elizabeth Reaser', 6),
#  ('Seth Green', 6),
#  ('Heather Graham', 6),
#  ('Jennifer Aniston', 6),
#  ('Sam Rockwell', 6),
#  ('Vivica A. Fox', 6),
#  ('Andy Samberg', 6),
#  ('Stephen Lang', 6),
#  ('Jacki Weaver', 6),
#  ('Marlon Wayans', 6),
#  ('Missi Pyle', 6),
#  ('Vince Vaughn', 6),
#  ('Harold Perrineau', 6),
#  ('Susan Sarandon', 6),
#  ('Tituss Burgess', 6),
#  ('Omari Hardwick', 6),
#  ('T.I.', 6),
#  ('Tim Blake Nelson', 6),
#  ('Matt Walsh', 6),
#  ('Cameron Diaz', 6),
#  ('Selma Blair', 6),
#  ('Thomas Jane', 6),
#  ('Meryl Streep', 6),
#  ('Tony Hale', 6),
#  ('Jennifer Coolidge', 6),
#  ('Jesse Plemons', 6),
#  ('Melissa Leo', 6),
#  ('Zoe Saldana', 6),
#  ('Nat Faxon', 6),
#  ('Amy Poehler', 6),
#  ('Paul Rudd', 6),
#  ('Patricia Clarkson', 6),
#  ('John Carroll Lynch', 6),
#  ('Clancy Brown', 6),
#  ("Vincent D'Onofrio", 6),
#  ('Johnny Depp', 6),
#  ('Mary Steenburgen', 6),
#  ('Jon Favreau', 6),
#  ('Dee Bradley Baker', 6),
#  ('Whoopi Goldberg', 6),
#  ('Christopher Mintz-Plasse', 6),
#  ('Riley Keough', 6),
#  ('Ashley Judd', 6),
#  ('Jane Krakowski', 6),
#  ('Mike Birbiglia', 6),
#  ('Emory Cohen', 6),
#  ('Jesse Eisenberg', 6),
#  ('Thomas Mann', 6),
#  ('Alan Cumming', 6),
#  ('Katt Williams', 6),
#  ('David Cross', 6),
#  ('Allen Covert', 6),
#  ('Emma Stone', 6),
#  ('Matt Damon', 6),
#  ('Evan Smith', 6),
#  ('Craig Sechler', 6),
#  ('Sylvester Stallone', 6),
#  ('Burt Young', 6),
#  ("Chris O'Dowd", 5),
#  ('Lynn Whitfield', 5),
#  ('Eva Mendes', 5),
#  ('Mary Elizabeth Winstead', 5),
#  ('Edward James Olmos', 5),
#  ('James Hong', 5),
#  ('Amanda Seyfried', 5),
#  ('John Turturro', 5),
#  ('Rosie Perez', 5),
#  ('Chris Tucker', 5),
#  ('Nia Long', 5),
#  ('Jack Nicholson', 5),
#  ('Martin Short', 5),
#  ('Carmen Electra', 5),
#  ('Greg Kinnear', 5),
#  ('Josh Lucas', 5),
#  ('Kurt Russell', 5),
#  ('Randall Park', 5),
#  ('Dylan McDermott', 5),
#  ('Michael Ealy', 5),
#  ('Uzo Aduba', 5),
#  ('Charlie Sheen', 5),
#  ('Philip Seymour Hoffman', 5),
#  ('Melora Walters', 5),
#  ('Dan Aykroyd', 5),
#  ('Richard Masur', 5),
#  ('Craig Robinson', 5),
#  ('Tommy Lee Jones', 5),
#  ('Marcia Gay Harden', 5),
#  ('Bruce McGill', 5),
#  ('Matthew McConaughey', 5),
#  ('Bryan Cranston', 5),
#  ('Jamie Foxx', 5),
#  ('Kerry Washington', 5),
#  ('Walton Goggins', 5),
#  ('Lochlyn Munro', 5),
#  ('Colin Farrell', 5),
#  ('Kirsten Dunst', 5),
#  ('Elle Fanning', 5),
#  ('Sarah Silverman', 5),
#  ('Billy Burke', 5),
#  ('Kellan Lutz', 5),
#  ('Nikki Reed', 5),
#  ('Bryce Dallas Howard', 5),
#  ('Michael Sheen', 5),
#  ('Jean-Claude Van Damme', 5),
#  ('Mark Wahlberg', 5),
#  ('Joe Don Baker', 5),
#  ('Josh Duhamel', 5),
#  ('Christina Hendricks', 5),
#  ('Mark Webber', 5),
#  ('Marc Maron', 5),
#  ('Taraji P. Henson', 5),
#  ('Anne Heche', 5),
#  ('David Carradine', 5),
#  ('Jason Mantzoukas', 5),
#  ('Brad Pitt', 5),
#  ('Guy Pearce', 5),
#  ('Jennifer Jason Leigh', 5),
#  ('Tom Sizemore', 5),
#  ('Neal McDonough', 5),
#  ('Siobhan Fallon Hogan', 5),
#  ('Juliette Lewis', 5),
#  ('Jason Bateman', 5),
#  ('Helen Mirren', 5),
#  ('Jacob Latimore', 5),
#  ('Jim Parsons', 5),
#  ('Alexa PenaVega', 5),
#  ('Daryl Sabara', 5),
#  ('Octavia Spencer', 5),
#  ('Jeffrey Wright', 5),
#  ('Meagan Good', 5),
#  ('Jessica Chastain', 5),
#  ('Parker Posey', 5),
#  ('Rosanna Arquette', 5),
#  ('Kevin Pollak', 5),
#  ('Gugu Mbatha-Raw', 5),
#  ('Abigail Breslin', 5),
#  ('Aaron Eckhart', 5),
#  ('Michelle Buteau', 5),
#  ('Danny Glover', 5),
#  ('Kristin Davis', 5),
#  ('Emile Hirsch', 5),
#  ('Wendell Pierce', 5),
#  ('Nick Nolte', 5),
#  ('Kevin Costner', 5),
#  ('Dustin Hoffman', 5),
#  ('Frank Langella', 5),
#  ('Patrick Wilson', 5),
#  ('Lili Taylor', 5),
#  ('Ron Livingston', 5),
#  ('John Corbett', 5),
#  ('Mark Ruffalo', 5),
#  ('Chris Parnell', 5),
#  ('Deon Cole', 5),
#  ('Wesley Snipes', 5),
#  ('Kate Bosworth', 5),
#  ('Johnny Knoxville', 5),
#  ('Vanessa Hudgens', 5),
#  ('Kumail Nanjiani', 5),
#  ('Casey Affleck', 5),
#  ('Amy Sedaris', 5),
#  ('Russell Peters', 5),
#  ('Jason Lee', 5),
#  ('Carlos Alazraqui', 5),
#  ('Haley Bennett', 5),
#  ('Bill Hader', 5),
#  ('Kristen Schaal', 5),
#  ('Brittany Snow', 5),
#  ('Chris Noth', 5),
#  ('Michael Gross', 5),
#  ('Nolan North', 5),
#  ('Mahershala Ali', 5),
#  ('Zachary Quinto', 5),
#  ('Cate Blanchett', 5),
#  ('Antonio Banderas', 5),
#  ('Kevin Michael Richardson', 5),
#  ('Allison Janney', 5),
#  ('Stephen Tobolowsky', 5),
#  ('Kate Walsh', 5),
#  ('Kevin Bacon', 5),
#  ('Alison Brie', 5),
#  ('Sharon Stone', 5),
#  ('Ludacris', 5),
#  ('Jerry Seinfeld', 5),
#  ("Chris D'Elia", 5),
#  ('Macon Blair', 5),
#  ('Jeff Bennett', 5),
#  ('Erica Ash', 5),
#  ('Iliza Shlesinger', 5),
#  ('Ciarán Hinds', 5),
#  ('Ben Affleck', 5),
#  ('Jay Duplass', 5),
#  ('Katherine McNamara', 5),
#  ('Peter Gallagher', 5),
#  ('Kari Wahlgren', 5),
#  ('Aziz Ansari', 5),
#  ('Maria Bamford', 5),
#  ('Jason Schwartzman', 5),
#  ('Lakeith Stanfield', 5),
#  ('David Strathairn', 5),
#  ('Troy Baker', 5),
#  ('Grey DeLisle', 5),
#  ('Mick Wingert', 5),
#  ('Tim Allen', 5),
#  ('Nicole Oliver', 5),
#  ('Kristen Bell', 5),
#  ('Mae Whitman', 5),
#  ('Brian White', 5),
#  ('Ogie Banks', 5),
#  ('Christopher Walken', 5),
#  ('Matthew Gray Gubler', 5),
#  ('Natasha Lyonne', 5),
#  ('Danny Flaherty', 5),
#  ('Bruce Greenwood', 5),
#  ('Lin Shaye', 5),
#  ('Yul Vazquez', 5),
#  ('Zachary Levi', 5),
#  ('Christopher Plummer', 5),
#  ('Billy Crudup', 5),
#  ('Kris Kristofferson', 5),
#  ('Kelly Sheridan', 5),
#  ('Chloë Grace Moretz', 5),
#  ('Ray Stevenson', 5),
#  ('Seann William Scott', 5),
#  ('Rip Torn', 5),
#  ('Alex Heartman', 5),
#  ('Erika Fong', 5),
#  ('Hector David Jr.', 5),
#  ('Najee De-Tiege', 5),
#  ('Brittany Anne Pirtle', 5),
#  ('Talia Shire', 5),
#  ('Samuel West', 5),
#  ('Richard Dreyfuss', 4),
#  ('Lea Thompson', 4),
#  ('Cliff Curtis', 4),
#  ('M. Emmet Walsh', 4),
#  ('Daryl Hannah', 4),
#  ('Bill Nunn', 4),
#  ('Frankie Faison', 4),
#  ('Angela Bassett', 4),
#  ('Queen Latifah', 4),
#  ('Omar Epps', 4),
#  ("Nasir 'Nas' Jones", 4),
#  ('Kenan Thompson', 4),
#  ('Kal Penn', 4),
#  ('Annette Bening', 4),
#  ('Ashton Kutcher', 4),
#  ('Jeffrey Tambor', 4),
#  ('Paul Reubens', 4),
#  ('RZA', 4),
#  ('Djimon Hounsou', 4),
#  ('James Earl Jones', 4),
#  ('Louis C.K.', 4),
#  ('Clint Eastwood', 4),
#  ('Rene Russo', 4),
#  ('John Mahoney', 4),
#  ('Gregory Alan Williams', 4),
#  ('Chris Messina', 4),
#  ('Bonnie Hunt', 4),
#  ('Nora Dunn', 4),
#  ('Jeff Bridges', 4),
#  ('Donald Sutherland', 4),
#  ('Courtney B. Vance', 4),
#  ('Cicely Tyson', 4),
#  ('Frances Fisher', 4),
#  ('Sandra Bullock', 4),
#  ('D.L. Hughley', 4),
#  ('Jessica Alba', 4),
#  ('Jessica Biel', 4),
#  ('Bradley Cooper', 4),
#  ('Hector Elizondo', 4),
#  ('Anne Hathaway', 4),
#  ('George Lopez', 4),
#  ('Leonardo DiCaprio', 4),
#  ('Oona Laurence', 4),
#  ('Bobby Moynihan', 4),
#  ('Reese Witherspoon', 4),
#  ('Bella Thorne', 4),
#  ('Scott Caan', 4),
#  ('Mike Myers', 4),
#  ('Michael York', 4),
#  ('Mimi Rogers', 4),
#  ('Burt Reynolds', 4),
#  ('Dylan Walsh', 4),
#  ('Jason Sudeikis', 4),
#  ('Aasif Mandvi', 4),
#  ('Barry Pepper', 4),
#  ('Jay Baruchel', 4),
#  ('Sacha Baron Cohen', 4),
#  ('Nick Searcy', 4),
#  ('Michael Douglas', 4),
#  ('Ralph Macchio', 4),
#  ('Pat Morita', 4),
#  ('Martin Kove', 4),
#  ('Stacy Keach', 4),
#  ('Pamela Reed', 4),
#  ('Larenz Tate', 4),
#  ('Scoot McNairy', 4),
#  ('Ben Mendelsohn', 4),
#  ('Lil Rel Howery', 4),
#  ('Paul Reiser', 4),
#  ('Demián Bichir', 4),
#  ('Theo Rossi', 4),
#  ('Rory Markham', 4),
#  ('Jonathan Sadowski', 4),
#  ('Affion Crockett', 4),
#  ('Dave Sheridan', 4),
#  ('Gabriel Iglesias', 4),
#  ('Radha Mitchell', 4),
#  ('John Heard', 4),
#  ('Ali Larter', 4),
#  ('Kim Coates', 4),
#  ('Vinnie Jones', 4),
#  ('Kelly Hu', 4),
#  ("Brían F. O'Byrne", 4),
#  ('Amy Smart', 4),
#  ('Michael Paré', 4),
#  ('Zach Grenier', 4),
#  ('Aaron Paul', 4),
#  ('Edward Norton', 4),
#  ('Jennifer Lopez', 4),
#  ('Dave Bautista', 4),
#  ('Joe Manganiello', 4),
#  ('Robert Forster', 4),
#  ('Clifton Collins Jr.', 4),
#  ('Dale Dickey', 4),
#  ('David Harbour', 4),
#  ('Jennifer Ehle', 4),
#  ('Paul Ben-Victor', 4),
#  ('Armand Assante', 4),
#  ('Samantha Mathis', 4),
#  ('Ty Consiglio', 4),
#  ('Robert Downey Jr.', 4),
#  ('David Schwimmer', 4),
#  ('Frances McDormand', 4),
#  ('Amanda Peet', 4),
#  ('Harland Williams', 4),
#  ('Ritchie Montgomery', 4),
#  ('Jason Mewes', 4),
#  ('Benedict Cumberbatch', 4),
#  ('Michelle Rodriguez', 4),
#  ('Fortune Feimster', 4),
#  ('Cassandra Morris', 4),
#  ('Ellie Kemper', 4),
#  ('Andrew Rannells', 4),
#  ('Hannah Marks', 4),
#  ('Chiwetel Ejiofor', 4),
#  ('Thandie Newton', 4),
#  ('Victor Garber', 4),
#  ('Benicio Del Toro', 4),
#  ('Edgar Ramírez', 4),
#  ('André Holland', 4),
#  ('Steve Coogan', 4),
#  ('Rashida Jones', 4),
#  ('Shirley Knight', 4),
#  ('Oscar Isaac', 4),
#  ('Nick Kroll', 4),
#  ('Lana Condor', 4),
#  ('Janel Parrish', 4),
#  ('Trezzo Mahoro', 4),
#  ('Ted Levine', 4),
#  ('Malin Akerman', 4),
#  ('Wanda Sykes', 4),
#  ('Winona Ryder', 4),
#  ('Uma Thurman', 4),
#  ('Catherine Keener', 4),
#  ('Crispin Glover', 4),
#  ('Margaret Cho', 4),
#  ('Christopher McDonald', 4),
#  ('Dylan Sprouse', 4),
#  ('Chadwick Boseman', 4),
#  ('Michael Kenneth Williams', 4),
#  ('Jon Heder', 4),
#  ('Maggie Gyllenhaal', 4),
#  ("Catherine O'Hara", 4),
#  ('Fred Willard', 4),
#  ('Zach Callison', 4),
#  ('Grey Griffin', 4),
#  ('Christine Baranski', 4),
#  ('Anna Faris', 4),
#  ('James Caan', 4),
#  ('Anika Noni Rose', 4),
#  ("Ahna O'Reilly", 4),
#  ('Marin Ireland', 4),
#  ('Aubrey Plaza', 4),
#  ('Wolfgang Novogratz', 4),
#  ('Leslie Mann', 4),
#  ('Taissa Farmiga', 4),
#  ('Mark Hamill', 4),
#  ('Robin Atkin Downes', 4),
#  ('June Squibb', 4),
#  ('Jackie Sandler', 4),
#  ('Brely Evans', 4),
#  ('Sebastian Stan', 4),
#  ('Matt Bomer', 4),
#  ('Robbie Amell', 4),
#  ('Ken Marino', 4),
#  ('Vincent Kartheiser', 4),
#  ('Billy Bob Thornton', 4),
#  ('Sean Bean', 4),
#  ('Joseph Gordon-Levitt', 4),
#  ('Allen Maldonado', 4),
#  ('Jim Jefferies', 4),
#  ('Haley Ramm', 4),
#  ('Charlize Theron', 4),
#  ('Anna Camp', 4),
#  ('Giovanni Ribisi', 4),
#  ('Kelsey Grammer', 4),
#  ('Zoey Deutch', 4),
#  ('Logan Miller', 4),
#  ('Helen Hunt', 4),
#  ('John Benjamin Hickey', 4),
#  ('Timothée Chalamet', 4),
#  ('Odeya Rush', 4),
#  ('Lauren Lapkus', 4),
#  ('Jack McBrayer', 4),
#  ('Bradley Whitford', 4),
#  ('Ed Helms', 4),
#  ('Tom Segura', 4),
#  ('Tony Goldwyn', 4),
#  ('Caitlin Fitzgerald', 4),
#  ('Josh Stamberg', 4),
#  ('Tim Roth', 4),
#  ('David Paymer', 4),
#  ('Kathy Baker', 4),
#  ('Adrian Pasdar', 4),
#  ('Tina Fey', 4),
#  ('Jennifer Love Hewitt', 4),
#  ('DeRay Davis', 4),
#  ('Mary Lynn Rajskub', 4),
#  ('Barry Bostwick', 4),
#  ('Rose McIver', 4),
#  ('Joe Pesci', 4),
#  ('Laura Marano', 4),
#  ('Michael Stuhlbarg', 4),
#  ('Ray Romano', 4),
#  ('Sebastian Maniscalco', 4),
#  ('Andrea Libman', 4),
#  ('Lily Rabe', 4),
#  ('Kate Berlant', 4),
#  ('Quincy Jones', 4),
#  ('Lynn Collins', 4),
#  ('Taye Diggs', 4),
#  ('Cheri Oteri', 4),
#  ('Rachel Dratch', 4),
#  ('Brie Larson', 4),
#  ('Diane Keaton', 4),
#  ('Cynthia Nixon', 4),
#  ('Yvette Nicole Brown', 4),
#  ("Liam O'Brien", 4),
#  ('Sam Kinison', 4),
#  ('Sarah Paulson', 4),
#  ('BD Wong', 4),
#  ('Rosemarie DeWitt', 4),
#  ('Andy Garcia', 4),
#  ('Tabitha St. Germain', 4),
#  ('Paul Giamatti', 4),
#  ('Christina Masterson', 4),
#  ('Russell Brand', 4),
#  ('Josh Brolin', 4),
#  ('Ben Schwartz', 4),
#  ('Jason Segel', 4),
#  ('Jared Leto', 4),
#  ('Thomas Lennon', 4),
#  ('Jack Black', 4),
#  ('J.B. Smoove', 4),
#  ('Ian McShane', 4),
#  ('Justin Timberlake', 4),
#  ('Kevin Nealon', 4),
#  ('Patton Oswalt', 4),
#  ('Robert Redford', 4),
#  ('Donald Faison', 4),
#  ('Regina Hall', 4),
#  ('Nelsan Ellis', 4),
#  ('Jake Johnson', 4),
#  ('Robert Longstreet', 4),
#  ('Nestor Serrano', 4),
#  ('Kevin Spacey', 4),
#  ('Anjelica Huston', 4),
#  ('Chris Pine', 4),
#  ('Michael Keaton', 4),
#  ('Thora Birch', 4),
#  ('Nehemiah Persoff', 4),
#  ('Dom DeLuise', 4),
#  ('Thomas Dekker', 4),
#  ('Kurt Fuller', 4),
#  ('Demi Moore', 4),
#  ('Cloris Leachman', 4),
#  ('Courteney Cox', 4),
#  ('Paul Sorvino', 4),
#  ('Christina Ricci', 4),
#  ('Richard Gere', 4),
#  ('Christopher Meloni', 4),
#  ('Cheech Marin', 4),
#  ('Harry Dean Stanton', 4),
#  ('50 Cent', 4),
#  ('Steve Carell', 4),
#  ('Thomas Haden Church', 4),
#  ('Celia Weston', 4),
#  ('Lance Henriksen', 4),
#  ('Fionnula Flanagan', 4),
#  ('Amber Valletta', 4),
#  ('Celeste Henderson', 4),
#  ('Steven Skyler', 4),
#  ('Rene Naufahu', 4),
#  ('Felix Ryan', 4),
#  ('Paul Schrier', 4),
#  ('Ving Rhames', 4),
#  ('Carl Weathers', 4),
#  ('Burgess Meredith', 4),
#  ('Tony Burton', 4),
#  ('Nona Gaye', 4),
#  ('Kevin Kline', 3),
#  ('Timothy Olyphant', 3),
#  ('Daveed Diggs', 3),
#  ('Skyler Gisondo', 3),
#  ('Tim Meadows', 3),
#  ('Keri Russell', 3),
#  ('Josh Hamilton', 3),
#  ('Lorraine Gary', 3),
#  ('Michael Caine', 3),
#  ('Tom Berenger', 3),
#  ('Harris Yulin', 3),
#  ('Dr. Dre', 3),
#  ('Macy Gray', 3),
#  ('Tadanobu Asano', 3),
#  ('Michiel Huisman', 3),
#  ('Channing Tatum', 3),
#  ('Henry Thomas', 3),
#  ('Giancarlo Esposito', 3),
#  ('Blake Lively', 3),
#  ('Peter Sarsgaard', 3),
#  ('Tim Robbins', 3),
#  ('Christopher Reid', 3),
#  ('Christopher Martin', 3),
#  ('Tisha Campbell', 3),
#  ("Tommy 'Tiny' Lister", 3),
#  ('Pam Grier', 3),
#  ('Hill Harper', 3),
#  ('David Patrick Kelly', 3),
#  ('Vanessa Redgrave', 3),
#  ('Steve Harvey', 3),
#  ('Michael J. Fox', 3),
#  ('Lukas Haas', 3),
#  ('Terence Stamp', 3),
#  ('Wes Studi', 3),
#  ('Eddie Izzard', 3),
#  ('Tom Waits', 3),
#  ('Jacinda Barrett', 3),
#  ('Freddy Rodríguez', 3),
#  ('Sean "P. Diddy" Combs', 3),
#  ('Method Man', 3),
#  ('Busta Rhymes', 3),
#  ('Renée Zellweger', 3),
#  ('Olivia Holt', 3),
#  ('Monica Bellucci', 3),
#  ('Cole Hauser', 3),
#  ('Johnny Messner', 3),
#  ('Lizzy Caplan', 3),
#  ('Timothy Simons', 3),
#  ('Larry Miller', 3),
#  ('Dave Chappelle', 3),
#  ('Michael Clarke Duncan', 3),
#  ('Adria Arjona', 3),
#  ('Justin Bartha', 3),
#  ('Anton Yelchin', 3),
#  ('Jennifer Lawrence', 3),
#  ('Lawrence Gilliard Jr.', 3),
#  ('Alphonso Mcauley', 3),
#  ('Willie Garson', 3),
#  ('P.J. Byrne', 3),
#  ('Pruitt Taylor Vince', 3),
#  ('Liv Tyler', 3),
#  ('Nicholle Tom', 3),
#  ('Chris Penn', 3),
#  ('Edie Falco', 3),
#  ('Aunjanue Ellis', 3),
#  ('Domenick Lombardozzi', 3),
#  ('Jamie Lee Curtis', 3),
#  ('Anna Chlumsky', 3),
#  ('Peter Michael Goetz', 3),
#  ('Ed Begley Jr.', 3),
#  ('Tobey Maguire', 3),
#  ("Michael O'Neill", 3),
#  ('James Cromwell', 3),
#  ('Emily Alyn Lind', 3),
#  ('Ryan Phillippe', 3),
#  ('Marisa Tomei', 3),
#  ('Emma Roberts', 3),
#  ('Dana Gourrier', 3),
#  ('Robin de Jesús', 3),
#  ('Nicole Kidman', 3),
#  ('Candice Bergen', 3),
#  ('Lake Bell', 3),
#  ('Reid Scott', 3),
#  ('Tiera Skovbye', 3),
#  ('Kate Hudson', 3),
#  ('Zooey Deschanel', 3),
#  ('Robert Wagner', 3),
#  ('Fred Savage', 3),
#  ('Elizabeth Hurley', 3),
#  ('Rob Lowe', 3),
#  ('Ernie Hudson', 3),
#  ('Katherine Heigl', 3),
#  ('Linden Ashby', 3),
#  ('Britt Robertson', 3),
#  ('Margo Martindale', 3),
#  ('Cameron Esposito', 3),
#  ('Sarah Chalke', 3),
#  ('Eric Christian Olsen', 3),
#  ('Sam Huntington', 3),
#  ('Bill Smitrovich', 3),
#  ('Kyle Bornheimer', 3),
#  ('Chris Elliott', 3),
#  ('Jean Smart', 3),
#  ('John Schneider', 3),
#  ('Chevy Chase', 3),
#  ('Josh Peck', 3),
#  ('Michaela Watkins', 3),
#  ('Dan Bakkedahl', 3),
#  ('John Gallagher Jr.', 3),
#  ('Sean Penn', 3),
#  ('James Rebhorn', 3),
#  ('Emily Ratajkowski', 3),
#  ('Evan Handler', 3),
#  ('Max Casella', 3),
#  ('John Ortiz', 3),
#  ('Julia Stiles', 3),
#  ('Tony Revolori', 3),
#  ('Jane Fonda', 3),
#  ('Isla Fisher', 3),
#  ('Mark Boone Junior', 3),
#  ('John Hawkes', 3),
#  ('Charlie Tahan', 3),
#  ('Will Yun Lee', 3),
#  ('Jermaine Love', 3),
#  ('Bertrand-Xavier Corbi', 3),
#  ('Katie Keene', 3),
#  ('Fernando Chien', 3),
#  ('Gina DeCesare', 3),
#  ('Michael Blalock', 3),
#  ('Chris Mulkey', 3),
#  ('Will Patton', 3),
#  ('Essence Atkins', 3),
#  ('Ashley Rickards', 3),
#  ('Gina Rodriguez', 3),
#  ('Morgan Fairchild', 3),
#  ('Gabrielle Union', 3),
#  ("Matt O'Leary", 3),
#  ('Chris Ellis', 3),
#  ('Val Kilmer', 3),
#  ('Matthew Perry', 3),
#  ('Jon Tenney', 3),
#  ('Thomas Kretschmann', 3),
#  ('Michelle Pfeiffer', 3),
#  ('Laura Dern', 3),
#  ('Isaiah Washington', 3),
#  ('Bill Bellamy', 3),
#  ('Hilary Swank', 3),
#  ('Richard Lawson', 3),
#  ('Bill Paxton', 3),
#  ('Hugh Jackman', 3),
#  ('Rose Byrne', 3),
#  ('Jason Ritter', 3),
#  ('Sarah Baker', 3),
#  ('Nina Dobrev', 3),
#  ('Bo Burnham', 3),
#  ('Kate Winslet', 3),
#  ('Keira Knightley', 3),
#  ('Ann Dowd', 3),
#  ('Matt Jones', 3),
#  ('Brian Stepanek', 3),
#  ('Garret Dillahunt', 3),
#  ('Tig Notaro', 3),
#  ('Joel McHale', 3),
#  ('Jeremy Piven', 3),
#  ('Ricky Gervais', 3),
#  ('Max Martini', 3),
#  ('Stefanie Scott', 3),
#  ('Seychelle Gabriel', 3),
#  ('Brian Tyree Henry', 3),
#  ('Michelle Monaghan', 3),
#  ('Jennifer Hudson', 3),
#  ('Jharrel Jerome', 3),
#  ('Josh Charles', 3),
#  ('Dean Winters', 3),
#  ('Madisen Beaty', 3),
#  ('Alex Zahara', 3),
#  ('Eric Roberts', 3),
#  ('Sally Kirkland', 3),
#  ('Jim Carrey', 3),
#  ('Neil Brown Jr.', 3),
#  ('Nathan Gamble', 3),
#  ('Kristen Johnston', 3),
#  ('Natasha Henstridge', 3),
#  ('Gabriel Basso', 3),
#  ('Tyler Labine', 3),
#  ('Jennifer Schwalbach', 3),
#  ('Lucas Till', 3),
#  ('Cory Hardrict', 3),
#  ('Jim Parrack', 3),
#  ('London Hughes', 3),
#  ('Brett Gelman', 3),
#  ('Katie Aselton', 3),
#  ('Rami Malek', 3),
#  ('Tony Plana', 3),
#  ('Drew Barrymore', 3),
#  ('Holland Taylor', 3),
#  ('Columbus Short', 3),
#  ('Lewis Black', 3),
#  ('Eric Bauza', 3),
#  ('John Cusack', 3),
#  ('Billy Zane', 3),
#  ('Dennis Haysbert', 3),
#  ('Idris Elba', 3),
#  ('Johnathon Schaech', 3),
#  ('Shia LaBeouf', 3),
#  ('Jason Clarke', 3),
#  ('Dane DeHaan', 3),
#  ('Mia Wasikowska', 3),
#  ('Sherri Shepherd', 3),
#  ('Eric André', 3),
#  ('Alain Moussi', 3),
#  ('Marie Avgeropoulos', 3),
#  ('Nate Bargatze', 3),
#  ('Matthew Modine', 3),
#  ('Taylor Kitsch', 3),
#  ('Ali Wong', 3),
#  ('Jenna Ortega', 3),
#  ('Tracie Thoms', 3),
#  ('Arturo Castro', 3),
#  ('Neville Archambault', 3),
#  ('Michael Chiklis', 3),
#  ('Micah Hauptman', 3),
#  ('Cobie Smulders', 3),
#  ('Sydney Park', 3),
#  ('Josephine Langford', 3),
#  ('Ike Barinholtz', 3),
#  ('Emily Mortimer', 3),
#  ('Joey King', 3),
#  ('Anna Cathcart', 3),
#  ('Emilija Baranac', 3),
#  ('Emayatzy Corinealdi', 3),
#  ('Sharon Lawrence', 3),
#  ('Kevin Sizemore', 3),
#  ('Elias Koteas', 3),
#  ('Josh Hutcherson', 3),
#  ('Dax Shepard', 3),
#  ('Chelsea Peretti', 3),
#  ('Christine Taylor', 3),
#  ('Ryan Hansen', 3),
#  ('Shameik Moore', 3),
#  ('Neal Huff', 3),
#  ('Peter Stormare', 3),
#  ('Jason Patric', 3),
#  ('Colleen Camp', 3),
#  ('Catherine Zeta-Jones', 3),
#  ('Maya Angelou', 3),
#  ('Raven-Symoné', 3),
#  ('Annabeth Gish', 3),
#  ('Lisa Kudrow', 3),
#  ('Tracey Ullman', 3),
#  ('Kyle Chandler', 3),
#  ('Dylan Arnold', 3),
#  ('Esai Morales', 3),
#  ('Glynn Turman', 3),
#  ('Mariah Carey', 3),
#  ('David Banner', 3),
#  ('Ali Afshar', 3),
#  ('Amanda Detmer', 3),
#  ('Brenda Song', 3),
#  ('Cher', 3),
#  ('Teresa Palmer', 3),
#  ('Jay Gragnani', 3),
#  ('Ramone Hamilton', 3),
#  ('Dayci Brookshire', 3),
#  ('Jorge Diaz', 3),
#  ('Lily Collins', 3),
#  ('Arliss Howard', 3),
#  ('Jared Harris', 3),
#  ('Scarlett Johansson', 3),
#  ("Sean O'Bryan", 3),
#  ('Casper Van Dien', 3),
#  ('Noah Kaye Bentley', 3),
#  ('Brennley Brown', 3),
#  ('Nicolas Cantu', 3),
#  ('Skai Jackson', 3),
#  ('Marsai Martin', 3),
#  ('Andre Robinson', 3),
#  ('Roger Craig Smith', 3),
#  ('Texas Battle', 3),
#  ('Miguel A. Núñez Jr.', 3),
#  ('Benjamin Bratt', 3),
#  ('Neil Patrick Harris', 3),
#  ('Phylicia Rashad', 3),
#  ('Johnny Simmons', 3),
#  ('Alexander Ludwig', 3),
#  ('Frank Whaley', 3),
#  ('Laia Costa', 3),
#  ('Maria Dizzia', 3),
#  ('Jeff Fahey', 3),
#  ('Christina Moore', 3),
#  ('Kristin Chenoweth', 3),
#  ('Jon Hamm', 3),
#  ('Tom Kane', 3),
#  ('James Ransone', 3),
#  ('John DiMaggio', 3),
#  ('Brian George', 3),
#  ('JP Karliak', 3),
#  ('Paris Berelc', 3),
#  ('Lavell Crawford', 3),
#  ('Camaron Engels', 3),
#  ('Jeremie Harris', 3),
#  ('Adam David Thompson', 3),
#  ('Charlie Carver', 3),
#  ('America Ferrera', 3),
#  ('Judah Lewis', 3),
#  ('Hana Mae Lee', 3),
#  ('Toni Collette', 3),
#  ('David Thewlis', 3),
#  ...]

# %%
# most popular 10 American actors who acted in the most production
cast_number_USA.most_common(10)
# Out:
# [('Adam Sandler', 20),
#  ('Samuel L. Jackson', 17),
#  ('Laura Bailey', 14),
#  ('Molly Shannon', 13),
#  ('James Franco', 13),
#  ('Nicolas Cage', 13),
#  ('Chris Rock', 12),
#  ('Dennis Quaid', 12),
#  ('Seth Rogen', 12),
#  ('Fred Tatasciore', 12)]

# %%
# Plot the most popular 10 American actors who acted in the most production as a bar chart
x, y = zip(*cast_number_USA.most_common(10))
plt.bar(x, y)
plt.title("Most Popular Actor In United States", fontweight = "bold", fontsize = 15)
plt.ylabel("Number Of Movie", fontweight = "bold", fontsize = 15)
plt.xticks(rotation = 90)
plt.show()

# %% [raw]
# ! "Adam Sandler" has shown herself to be by far the most popular actor, starring in 20 separate productions.
# ! Then, respectively, "Samuel L. Jackson" and "Laura Bailey" come.

# %% [raw]
# ! In the USA, the closest working actor/director pairs are typically those with a strong working relationship.
# ! For example, we can mention the compatibility of "Robert De Niro" who also appeared in 4 different Martin Scorsese movies;
# ! "Harrison Ford" who also appeared in 4 "Indiana Jones" series movies directed by "Steven Spielberg"; "Alexa Vega" and
# ! "Darly Sabara", who also appeared in 4 "Spy Kids" series movies directed by "Robert Rodriguez". Also "Talia Shire",
# ! "Burt Young" and "Carl Weathers", who acted together with "Sylvester Stallone" are compatible actors with the director.
# ! As in the example of Yılmaz Erdoğan in Turkey, "Sylvester Stallone" acted in 3 different "Rocky" films he directed.
# ! We can say  there is a strong relationship between Robert De Niro and Martin Scorsese. Because they worked together
# ! at least 4 movies and these movies are not a serial type.

# %% [raw]
# ! In the USA, the closest working and compatible actors are usually those who have acted together in more than one movie.
# ! For example, the most collaborative actors in the USA are "Alexa Vega" and "Darly Sabara", who acted together in 4 movies
# ! in the "Spy Kids" series. "Antonio Banderas" accompanied them in 3 films of the same film series. "Sylvester Stallone",
# ! "Talia Shire", "Burt Young", "Carl Weathers", who acted together in 3 films in the "Rocky" film series; "Keanu Reeves",
# ! "Laurence Fishburne", "Carrie-Anne Moss", "Hugo Weaving", who acted together in 3 films in the "Matrix" series and
# ! "Will Yun Lee", "Jermaine Love","Rory Markham", "Bertrand-Xavier Corbi" who acted together in 3 films in the "Rogue Warfare"
# ! series may be included in . As you can see, due to the nature of serial films, the same actors come together.
# ! In the USA, it is possible to say that the genre of serial films in which the actors often act together is in the
# ! action/adventure genre, unlike Turkey.

# %% [markdown]
# ### Generating New Features

# %% [raw]
# ! we decided to deeper our review of movies shorter than 60 minutes
# ! as you know, Netflix was a DVD rental company. After 2007, it started to broadcast content over the internet
# ! let's re-examine the records after 2007

# %%
# content added after 2007
df_after = df[df["added_year"] > 2007]

# %%
#selecting releated fields
df_after = df_after[["type","title","country","genre","release_year","added_year","production","rating_age","duration"]]

# %%
Type2 = df_after.groupby("type").size()
Type2.plot(kind = "pie", title = "Distribution By Type After 2007", ylabel = "", figsize = [10,6], shadow = True,
          autopct = lambda p:"{:.2f}%({:.0f})".format(p,(p/100)*Type2.sum()))

# save pie plot as png
plt.savefig(fname = "graphic1.png", transparent = True)

# show pie plot
plt.show()

# %%
# duration averages, median, minimum and maximum values of content added after 2007 by type
df_after.groupby("type")["duration"].agg(["mean","min","max","median","count"])
# Out:
#           mean  min  max  median  count
# type
# Movie   99.455    3  312  98.000   6100
# TV Show  1.753    1   17   1.000   2658

# %% [raw]
# ! the average duration of movies was 99 minutes for 6100 movies

# %%
# average duration of content added after 2007 by type and genre
df_after.groupby(["type","genre"])["duration"].agg(["mean","min","max","count"])
# Out:
#                          mean  min  max  count
# type    genre
# Movie   Children       79.749    3  152    622
#         Documentaries  81.636   10  273    867
#         Other         108.529    5  312   4268
#         Stand-Up       67.327   28  146    343
# TV Show Other           1.751    1   17   2602
#         Stand-Up        1.839    1   13     56

# %% [raw]
# ! the average duration of movies is 79 minutes for the children genre, 81 minutes for documentaries genre,
# ! 67 minutes for stand up genre and 108 minutes for other genre

# %%
# average duration of content added after 2007 by type, genre and rating age
df_after.groupby(["type","genre","rating_age"])["duration"].agg(["mean","min","max","count"])
# Out:
#                                     mean  min  max  count
# type    genre         rating_age
# Movie   Children      Adults     116.000  116  116      1
#                       Kids        63.323    3  146    189
#                       Older Kids  85.533   14  139    405
#                       Teen       106.630   81  152     27
#         Documentaries Adults      88.585   22  208    347
#                       Kids        68.731   10  273     52
#                       Not Rated   86.909   61  110     22
#                       Older Kids  71.000   12  156    187
#                       Teen        82.147   14  141    259
#         Other         Adults     104.782   12  312   2213
#                       Kids        78.491   15  181     53
#                       Not Rated  101.220   79  143     50
#                       Older Kids 109.197   13  233    370
#                       Teen       114.851    5  253   1582
#         Stand-Up      Adults      67.349   28  146    298
#                       Kids        54.667   46   60      3
#                       Not Rated   68.200   44   85      5
#                       Older Kids  60.429   42   71      7
#                       Teen        69.833   57  101     30
# TV Show Other         Adults       1.678    1   12   1105
#                       Kids         1.864    1   10    265
#                       Not Rated    1.667    1    3      3
#                       Older Kids   1.783    1   11    511
#                       Teen         1.799    1   17    718
#         Stand-Up      Adults       1.789    1   13     38
#                       Kids         1.000    1    1      2
#                       Not Rated    1.000    1    1      1
#                       Older Kids   1.200    1    2      5
#                       Teen         2.600    1    6     10

# %%
# cross-tabulate added_year and genre
pd.crosstab(df_after["added_year"], df_after["genre"],
            values = df_after["duration"], aggfunc = ["mean","min","max","count"]).T
# Out:
# added_year            2008    2009   2010    2011   2012    2013    2014  \
#       genre
# mean  Children         NaN     NaN    NaN  75.000 26.000 130.000  81.250
#       Documentaries    NaN     NaN    NaN     NaN 76.000 100.000  87.125
#       Other         81.000  66.500 84.000  95.000 84.000   4.000  21.250
#       Stand-Up       1.000     NaN    NaN     NaN    NaN  54.400  73.750
# min   Children         NaN     NaN    NaN  75.000 26.000 130.000  71.000
#       Documentaries    NaN     NaN    NaN     NaN 76.000 100.000  35.000
#       Other         81.000  29.000 84.000  93.000 84.000   1.000   3.000
#       Stand-Up       1.000     NaN    NaN     NaN    NaN   1.000  68.000
# max   Children         NaN     NaN    NaN  75.000 26.000 130.000 103.000
#       Documentaries    NaN     NaN    NaN     NaN 76.000 100.000 105.000
#       Other         81.000 104.000 84.000 103.000 84.000   6.000  72.000
#       Stand-Up       1.000     NaN    NaN     NaN    NaN  80.000  81.000
# count Children         NaN     NaN    NaN   1.000  1.000   1.000   4.000
#       Documentaries    NaN     NaN    NaN     NaN  1.000   1.000   8.000
#       Other          1.000   2.000  1.000  12.000  1.000   4.000   8.000
#       Stand-Up       1.000     NaN    NaN     NaN    NaN   5.000   4.000
#
# added_year             2015    2016    2017     2018     2019     2020  \
#       genre
# mean  Children       75.000  57.600  77.431   80.226   80.336   79.293
#       Documentaries  82.000  82.706  81.466   81.946   78.332   84.263
#       Other          43.587  39.460  64.535   77.572   69.868   68.249
#       Stand-Up       71.923  67.800  58.521   55.551   57.507   55.500
# min   Children       47.000  23.000  14.000   11.000    3.000    9.000
#       Documentaries  29.000  25.000  18.000   12.000   10.000   15.000
#       Other           1.000   1.000   1.000    1.000    1.000    1.000
#       Stand-Up       58.000   5.000   1.000    1.000    1.000    1.000
# max   Children       93.000  96.000 117.000  152.000  135.000  146.000
#       Documentaries 103.000 117.000 156.000  136.000  142.000  208.000
#       Other         155.000 180.000 179.000  312.000  228.000  253.000
#       Stand-Up       92.000  94.000 102.000  146.000  104.000   85.000
# count Children       11.000  20.000  72.000   84.000  143.000  164.000
#       Documentaries  12.000  68.000 206.000  167.000  187.000  118.000
#       Other          46.000 298.000 830.000 1286.000 1597.000 1537.000
#       Stand-Up       13.000  40.000  73.000  107.000   75.000   56.000
#
# added_year              2021
#       genre
# mean  Children        84.835
#       Documentaries   83.222
#       Other           66.148
#       Stand-Up        53.760
# min   Children        13.000
#       Documentaries   14.000
#       Other            1.000
#       Stand-Up         1.000
# max   Children       139.000
#       Documentaries  273.000
#       Other          229.000
#       Stand-Up       111.000
# count Children       121.000
#       Documentaries   99.000
#       Other         1247.000
#       Stand-Up        25.000

# %%
# duration statistics of content added after 2007 according to the year they were added
df_after.groupby(["type","added_year"])["duration"].agg(["mean","min","max","count"])
# Out:
#                       mean  min  max  count
# type    added_year
# Movie   2008        81.000   81   81      1
#         2009        66.500   29  104      2
#         2010        84.000   84   84      1
#         2011        93.462   75  103     13
#         2012        62.000   26   84      3
#         2013        83.500   44  130      6
#         2014        77.000   26  105     19
#         2015        83.571   29  155     56
#         2016        83.614   22  180    251
#         2017        95.681   14  179    832
#         2018       101.651   11  312   1234
#         2019        99.722    3  228   1415
#         2020       101.445    5  253   1280
#         2021       102.682   12  273    987
# TV Show 2008         1.000    1    1      1
#         2013         3.400    1    6      5
#         2014         4.800    3    8      5
#         2015         2.654    1   10     26
#         2016         1.486    1    9    175
#         2017         1.679    1   12    349
#         2018         1.680    1   15    410
#         2019         1.571    1   13    587
#         2020         1.854    1   15    595
#         2021         1.956    1   17    505

# %% [raw]
# ! observation 12: although Netflix started broadcasting over the internet after 2007, we see an accumulation after 2016.
# ! let's look at the after 2016.

# %%
# movies added since 2016
netflix_movies_2016 = df_after[df_after["added_year"] >= 2016]

# %%
# duration average of production after 2007
df_after.groupby(["production"])["duration"].agg(["mean","min","max","count"])
# Out:
#              mean  min  max  count
# production
# N          52.196    1  312   3221
# O          80.046    1  253   5537

# %%
# duration average of production after 2016
netflix_movies_2016.groupby(["production"])["duration"].agg(["mean","min","max","count"])
# Out:
#              mean  min  max  count
# production
# N          51.827    1  312   3144
# O          80.339    1  253   5476

# %%
# demonstrate distribution by production after 2016
Type3 = netflix_movies_2016.groupby("production").size()
Type3.plot(kind = "pie", title = "Distribution By Production After 2016", ylabel = "", figsize = [10,6], shadow = True,
          autopct = lambda p:"{:.2f}%({:.0f})".format(p,(p/100)*Type3.sum()))

# save pie plot as png
plt.savefig(fname = "graphic1.png", transparent = True)

# show pie plot
plt.show()

# %% [raw]
# ! observation 13: 8620 movies added since 2016
# ! 3144 of these movies were made by Netflix
# ! the longest movie made by Netflix is 312 minutes
# ! the longest movie made by other production is 253 minutes
# ! 63.53 percent of the movies added belong to other producers
# ! 36.47 percent of the movies added belong to Netflix

# %%
# finding duration statictic by production and added_year since 2016
netflix_movies_2016.groupby(["production","added_year"])["duration"].agg(["mean","min","max","count"])
# Out:
#                         mean  min  max  count
# production added_year
# N          2016       56.550    1  132    189
#            2017       63.844    1  166    379
#            2018       57.102    1  312    559
#            2019       51.439    1  209    659
#            2020       46.147    1  190    775
#            2021       45.417    1  273    583
# O          2016       44.553    1  180    237
#            2017       69.820    1  179    802
#            2018       86.826    1  214   1085
#            2019       80.514    1  228   1343
#            2020       86.535    1  253   1100
#            2021       83.451    1  229    909

# %% [raw]
# ! according to statictic above the line, every year the maximum values of movies are increasing
# ! we also see big changes in the number of movies added

# %%
# finding duration statictic by production, added_year and genre since 2016
netflix_movies_2016.groupby(["production","added_year","genre"])["duration"].agg(["mean","min","max","count"])
# Out:
#                                       mean  min  max  count
# production added_year genre
# N          2016       Children      68.625   23   96      8
#                       Documentaries 83.294   25  117     34
#                       Other         44.825    1  132    114
#                       Stand-Up      66.576    5   94     33
#            2017       Children      72.565   14  117     23
#                       Documentaries 83.986   19  144     71
#                       Other         57.357    1  166    224
#                       Stand-Up      60.934    1  102     61
#            2018       Children      77.645   25  110     31
#                       Documentaries 77.880   12  124     50
#                       Other         53.787    1  312    409
#                       Stand-Up      52.464    1  113     69
#            2019       Children      71.981   24  114     54
#                       Documentaries 76.441   10  142     68
#                       Other         45.182    1  209    483
#                       Stand-Up      55.370    1   91     54
#            2020       Children      65.173    9  124     75
#                       Documentaries 77.035   15  114     57
#                       Other         40.106    1  190    595
#                       Stand-Up      54.625    1   85     48
#            2021       Children      87.000   13  139     39
#                       Documentaries 81.396   14  273     53
#                       Other         37.949    1  159    472
#                       Stand-Up      45.211    1   98     19
# O          2016       Children      50.250   24   88     12
#                       Documentaries 82.118   29  111     34
#                       Other         36.136    1  180    184
#                       Stand-Up      73.571   65   81      7
#            2017       Children      79.714   22  109     49
#                       Documentaries 80.141   18  156    135
#                       Other         67.188    1  179    606
#                       Stand-Up      46.250    1   96     12
#            2018       Children      81.736   11  152     53
#                       Documentaries 83.684   29  136    117
#                       Other         88.665    1  214    877
#                       Stand-Up      61.158    1  146     38
#            2019       Children      85.404    3  135     89
#                       Documentaries 79.412   20  124    119
#                       Other         80.571    1  228   1114
#                       Stand-Up      63.000    1  104     21
#            2020       Children      91.191   11  146     89
#                       Documentaries 91.016   44  208     61
#                       Other         86.024    1  253    942
#                       Stand-Up      60.750    1   76      8
#            2021       Children      83.805   22  127     82
#                       Documentaries 85.326   38  141     46
#                       Other         83.323    1  229    775
#                       Stand-Up      80.833    2  111      6

# %%
# genre versus production since 2016
netflix_movies_2016.groupby(["production","genre"]).count()
# Out:
#                           type  title  country  release_year  added_year  \
# production genre
# N          Children        230    230      230           230         230
#            Documentaries   333    333      333           333         333
#            Other          2297   2297     2297          2297        2297
#            Stand-Up        284    284      284           284         284
# O          Children        374    374      374           374         374
#            Documentaries   512    512      512           512         512
#            Other          4498   4498     4498          4498        4498
#            Stand-Up         92     92       92            92          92
#
#                           rating_age  duration
# production genre
# N          Children              230       230
#            Documentaries         333       333
#            Other                2297      2297
#            Stand-Up              284       284
# O          Children              374       374
#            Documentaries         512       512
#            Other                4498      4498
#            Stand-Up               92        92

# %% [raw]
# ! Netflix seems to care more about certain genres such as stand up
# ! let's see

# %%
# movies added since 2016 filtered by production
netflix_movies_O = netflix_movies_2016[netflix_movies_2016["production"] == "O"]
netflix_movies_N = netflix_movies_2016[netflix_movies_2016["production"] == "N"]

# %%
# duration average of Netflix movies added since 2016 by genre
netflix_movies_N.groupby("genre")["duration"].mean()
# Out:
# genre
# Children        73.013
# Documentaries   79.856
# Other           45.083
# Stand-Up        56.356
# Name: duration, dtype: float64

# %%
# duration average of other producer movies added since 2016 by genre
netflix_movies_O.groupby("genre")["duration"].mean()
# Out:
# genre
# Children        84.037
# Documentaries   82.674
# Other           80.145
# Stand-Up        61.826
# Name: duration, dtype: float64

# %%
# percentage of production of content added since 2016 by genre for Netflix
netflix_movies_N["genre"].value_counts()
genre_N = netflix_movies_N.groupby("genre").size()
genre_N.plot(kind = "pie", title = "Number Of Genre By Production N", figsize = [5,5], shadow = True, ylabel = "",
          autopct = lambda p:"{:.2f}%({:.0f})".format(p,(p/100)*genre_N.sum()))
plt.show()

# %%
# percentage of production of content added since 2016 by genre for other producer
netflix_movies_O["genre"].value_counts()
genre_O = netflix_movies_O.groupby("genre").size()
genre_O.plot(kind = "pie", title = "Number Of Genre By Production O", figsize = [5,5], shadow = True, ylabel = "",
          autopct = lambda p:"{:.2f}%({:.0f})".format(p,(p/100)*genre_O.sum()))
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.countplot(y = "genre", hue = "production", data = netflix_movies_2016)
plt.title("Genre VS Production", fontweight = "bold", fontsize = 15)
plt.ylabel("Genre", fontweight = "bold", fontsize = 15)
plt.show()

# %%
# create new field called year_count
df_after["year_count"] = df_after.apply(lambda x: x["added_year"] - x["release_year"], axis=1)

# %%
# show the field
df_after["year_count"]
# Out:
# show_id
# s1        1
# s2        0
# s3        0
# s4        0
# s5        0
#          ..
# s8803    12
# s8804     1
# s8805    10
# s8806    14
# s8807     4
# Name: year_count, Length: 8758, dtype: int64

# %%
# apply a function for fill to field year_count
netflix_movies_2016["year_count"] = netflix_movies_2016.apply(lambda x: x["added_year"] - x["release_year"], axis=1)

# %%
# apply filter and create new data frame
other_movies = netflix_movies_2016[(netflix_movies_2016["production"] == "O") & (netflix_movies_2016["type"] == "Movie")]

# %%
# show statictic for field year_count
other_movies["year_count"].agg(["median","min","max", "mean"])
# Out:
# median    4.000
# min      -1.000
# max      75.000
# mean      8.219
# Name: year_count, dtype: float64

# %% [markdown]
# ### Generating Hypotheses

# %%
# don't display record before 1970 
# we assumed it was the outlier
short_movies_no_outliers = short_movies[short_movies["release_year"] > 1970]

# %%
# we have to regenerate this function because of we assumed records before 1970 were the outlier.
colors = []

# iterate over rows of short_movies
for x, row in short_movies_no_outliers.iterrows() :
    if row["genre"] == "Children":
        colors.append("red")
    elif row["genre"] == "Documentaries":
        colors.append("blue")
    elif row["genre"] == "Stand-Up":
        colors.append("green")
    else:
        colors.append("yellow")
        
# inspect the first 5 values in list        
colors[:5]
# Out:
# ['blue', 'red', 'red', 'red', 'yellow']

# %%
# create a scatter plot of duration versus release_year
plt.scatter(short_movies_no_outliers.release_year, short_movies_no_outliers.duration, color=colors)

# create a title and axis labels
plt.title("Movie Duration By Year Of Release")
plt.xlabel("Release year")
plt.ylabel("Duration (min)")

# save scatter plot as png
plt.savefig(fname = "grafic2.png")

# show the plot
plt.show()

# %% [raw]
# ! particularly in recent years, there has been an increase in the number of content and genres less than 60 min.
# ! there has been visibly decrease, movies minimum duration

# %%
# create a relplot of duration versus release_year
sns.relplot(x = "release_year", y = "duration", data = short_movies_no_outliers, ci = None, hue = colors, kind = "line", 
            height = 4, aspect = 6)
plt.title("Are we certain that movies are getting shorter?", fontweight = "bold", fontsize = 15 )
plt.ylabel("Duration", fontweight = "bold", fontsize = 15)

# save relplot as png
plt.savefig(fname="grafic3.png")

# show the plot
plt.show()

# %% [raw]
# ! according to relplot above the line; there has been a decrease in the duration of the children and documentries
# ! there has been an increase in the duration of the stand up

# %% [raw]
# ! there is no reduction in the average duration of movies
# ! but there is an increase in the number of movies of less than 60 minutes

# %%
# demonstrate distribution by production after 2016
Type3 = netflix_movies_2016.groupby("production").size()
Type3.plot(kind = "pie", title = "Distribution By Production After 2016", ylabel = "", figsize = [10,6], shadow = True,
          autopct = lambda p:"{:.2f}%({:.0f})".format(p,(p/100)*Type3.sum()))

# save pie plot as png
plt.savefig(fname = "graphic1.png", transparent = True)

# show pie plot
plt.show()

# %% [raw]
# ! after 2007, Netflix started broadcasting over the internet
# ! since 2016, there has been a significant increase in the number of movies it has added.

# %% [raw]
# ! after 2016,
# ! 63.53 % of the movies on Netflix belong to other producers
# ! 36.47 % of the movies on Netflix belong to Netflix
# ! Netflix 729.4% growth in 5 years

# %%
netflix_movies_2016 = netflix_movies_2016[(netflix_movies_2016["production"] == "N") & (netflix_movies_2016["type"] == "Movie")]

# %%
netflix_movies_2016["release_year"].value_counts().plot(kind = "bar", )
# Out:
# <Axes: >

# %% [raw]
# *******************************************************************************************************************************

# %% [raw]
# ! The most popular directors to work with in Turkey are "Hakan Algül" and "Yılmaz Erdoğan".
# ! "Hakan Algul" 8 movie; "Yılmaz Erdoğan" directed 7 movies and a theater play, most of which he was involved in as an actor.

# %% [raw]
# ! "Demet Akbağ", who acted 13 films in total, worked with 2 different directors who directed the most productions in Turkey
# ! in 7 films (one theater play), proved to be the most popular actress by far.
# ! Then, respectively, "Cezmi Baskin" and "Salih Kalyon" come.

# %% [raw]
# ! Actors who work closely and are compatible with each other in Turkey are usually actors who have acted together
# ! in more than one movie. For example, the most cooperative players in Turkey are "Demet Akbağ" and "Ata Demirer".
# ! They have acted in 4 movies together. Ozge Borak and Salih Kalyon, with whom they played together in the same film series
# ! (Eyyvah Eyyvah), can be included. As can be seen, although the same actors come together due to the nature of the serial films,
# ! it is noteworthy that most of these films are in the "comedy" genre.

# %% [raw]
# ! The closest working actor/director pairs in Turkey are typically those with a strong working relationship.
# ! For example, the most collaborating actor/director trio in Turkey is "Demet Akbağ", "Ata Demirer" and "Hakan Algül".
# ! "They worked together in 4 projects in total.

# %% [raw]
# *******************************************************************************************************************************

# %% [raw]
# ! The most popular directors to work with in the USA are "Martin Scorsese", "Steven Spielberg" and "Robert Rodriguez".
# ! "Martin Scorsese" directed 8 movies, "Steven Spielberg" and Robert Rodriguez" directed 6 movies

# %% [raw]
# ! "Adam Sandler" has shown herself to be by far the most popular actor, starring in 20 separate productions.
# ! Then, respectively, "Samuel L. Jackson" and "Laura Bailey" come.

# %% [raw]
# ! In the USA, the closest working actor/director pairs are typically those with a strong working relationship.
# ! For example, we can mention the compatibility of "Robert De Niro" who also appeared in 4 different Martin Scorsese movies;
# ! "Harrison Ford" who also appeared in 4 "Indiana Jones" series movies directed by "Steven Spielberg"; "Alexa Vega" and
# ! "Darly Sabara", who also appeared in 4 "Spy Kids" series movies directed by "Robert Rodriguez". Also "Talia Shire",
# ! "Burt Young" and "Carl Weathers", who acted together with "Sylvester Stallone" are compatible actors with the director.
# ! As in the example of Yılmaz Erdoğan in Turkey, "Sylvester Stallone" acted in 3 different "Rocky" films he directed.
# ! We can say  there is a strong relationship between Robert De Niro and Martin Scorsese. Because they worked together
# ! at least 4 movies and these movies are not a serial type.

# %% [raw]
# ! In the USA, the closest working and compatible actors are usually those who have acted together in more than one movie.
# ! For example, the most collaborative actors in the USA are "Alexa Vega" and "Darly Sabara", who acted together in 4 movies
# ! in the "Spy Kids" series. "Antonio Banderas" accompanied them in 3 films of the same film series. "Sylvester Stallone",
# ! "Talia Shire", "Burt Young", "Carl Weathers", who acted together in 3 films in the "Rocky" film series; "Keanu Reeves",
# ! "Laurence Fishburne", "Carrie-Anne Moss", "Hugo Weaving", who acted together in 3 films in the "Matrix" series and
# ! "Will Yun Lee", "Jermaine Love","Rory Markham", "Bertrand-Xavier Corbi" who acted together in 3 films in the "Rogue Warfare"
# ! series may be included in . As you can see, due to the nature of serial films, the same actors come together.
# ! In the USA, it is possible to say that the genre of serial films in which the actors often act together is in the
# ! action/adventure genre, unlike Turkey.

# %% [markdown]
# ![Metamy%20Logo3.jpg](attachment:Metamy%20Logo3.jpg)
